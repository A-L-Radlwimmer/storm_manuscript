# %% [markdown]
# # Fraser, A.D. and Massom, R. (2020) Circum-Antarctic landfast sea ice extent, 2000-2018, Ver. 2.2, Australian Antarctic Data Centre - doi:10.26179/5d267d1ceb60c, Accessed: 2026-01-04

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import colorcet as cc
import os
from pyproj import Transformer

# %%
year = 2000
ds = xr.open_mfdataset("AAS_4116_Fraser_fastice_circumantarctic/fastice_v2_2/FastIce_70_"+str(year)+".nc", combine="by_coords", data_vars="minimal", coords="minimal", compat="override")
#ds = xr.open_mfdataset("AAS_4116_Fraser_fastice_circumantarctic/fastice_v2_2/FastIce_70_200*.nc", combine="by_coords", data_vars="minimal", coords="minimal", compat="override")
ds
# Out:
# <xarray.Dataset> Size: 952MB
# Dimensions:               (X: 5625, Y: 4700, time: 20)
# Coordinates:
#   * time                  (time) datetime64[ns] 160B 2000-03-01 ... 2000-12-11
# Dimensions without coordinates: X, Y
# Data variables:
#     x                     (X) float64 45kB dask.array<chunksize=(5625,), meta=np.ndarray>
#     y                     (Y) float64 38kB dask.array<chunksize=(4700,), meta=np.ndarray>
#     latitude              (Y, X) float32 106MB dask.array<chunksize=(4700, 5625), meta=np.ndarray>
#     longitude             (Y, X) float32 106MB dask.array<chunksize=(4700, 5625), meta=np.ndarray>
#     area                  (Y, X) float64 212MB dask.array<chunksize=(4700, 5625), meta=np.ndarray>
#     date_alt              (time) int32 80B dask.array<chunksize=(20,), meta=np.ndarray>
#     Fast_Ice_Time_series  (time, Y, X) int8 529MB dask.array<chunksize=(3, 784, 938), meta=np.ndarray>
# Attributes:
#     title:        Fast ice time series
# ...

# %% [markdown]
# # Add ice-ages

# %%
ice = ds.Fast_Ice_Time_series.compute()
time = ds.time.compute()
last = ice.isel(time=-1)

fast_ice = last.isin([4, 5, 6])

ice_rev = ice.isel(time=slice(None, None, -1))
zero_rev = ice_rev == 0
last_zero_rev_idx = zero_rev.argmax(dim="time")
had_zero = zero_rev.any(dim="time")
last_zero_idx = (ice.sizes["time"] - 1) - last_zero_rev_idx

formation_date = xr.full_like(last, fill_value=np.datetime64("NaT"), dtype="datetime64[ns]")
formation_date = formation_date.where(~(fast_ice & had_zero), time.isel(time=last_zero_idx))
multi_year = fast_ice & ~had_zero
static_type = last.where(last.isin([1, 2, 3]))

fd = formation_date
day = fd.dt.day
month = fd.dt.month
formation_date_int = xr.full_like(day, -1, dtype=np.int16)
formation_date_int = formation_date_int.where(~(day <= 2), (month - 1) * 2)
formation_date_int = formation_date_int.where(~((day >= 11) & (day <= 17)), (month - 1) * 2 + 1)
formation_date_int = formation_date_int.where(~(day >= 26), ((month - 1) * 2 + 2) % 24)
formation_date_int = formation_date_int.where(fd.notnull())

ds = ds.assign(
    formation_date=formation_date,
    multi_year_fast_ice=multi_year,
    static_surface_type=static_type,
    formation_date_int=formation_date_int
)

# %% [markdown]
# # Add extents (within bounding box)

# %%
bounding_lat_min, bounding_lat_max = -78.1, -77.46
bounding_lon_min, bounding_lon_max = 163.4, 167.0

# %%
# Total area in December
fi_december = ds.Fast_Ice_Time_series.isel(time=-1)
spatial_mask = ((ds.latitude >= bounding_lat_min) & (ds.latitude <= bounding_lat_max) & (ds.longitude >= bounding_lon_min) & (ds.longitude <= bounding_lon_max))
value_mask = fi_december.isin([4, 5, 6])
mask = spatial_mask & value_mask
count = ds.area.where(mask).sum().compute().values
print(count)
# Out:
# 2276.8737310628712

# %%
masked_area = ds.area.where(spatial_mask, 0)

evanescent_mask = ds.Fast_Ice_Time_series.isin([4, 5, 6])
evanescent_extent = xr.dot(evanescent_mask, masked_area, dims=("Y", "X"))

init_extent = (ds.multi_year_fast_ice * masked_area).sum(dim=("Y", "X"))
new_extent_mask = (ds.formation_date_int.expand_dims(time=ds.time) == xr.DataArray(np.arange(ds.dims["time"]), dims="time", coords={"time": ds.time}))
new_extent = xr.dot(new_extent_mask, masked_area, dims=("Y", "X"))

# Cumulative extent
extent = init_extent + new_extent.shift(time=1, fill_value=0).cumsum(dim="time")

ds = ds.assign(evanescent_extent=evanescent_extent, extent=extent)
ds
# Out:
# C:\Users\Homo Naledi\AppData\Local\Temp\ipykernel_6268\3192071585.py:7: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   new_extent_mask = (ds.formation_date_int.expand_dims(time=ds.time) == xr.DataArray(np.arange(ds.dims["time"]), dims="time", coords={"time": ds.time}))
# <xarray.Dataset> Size: 2GB
# Dimensions:               (X: 5625, Y: 4700, time: 20)
# Coordinates:
#   * time                  (time) datetime64[ns] 160B 2000-03-01 ... 2000-12-11
# Dimensions without coordinates: X, Y
# Data variables: (12/13)
#     x                     (X) float64 45kB dask.array<chunksize=(5625,), meta=np.ndarray>
#     y                     (Y) float64 38kB dask.array<chunksize=(4700,), meta=np.ndarray>
# ...

# %%
## Convert array to a string of space-separated values
#ev_vals = " ".join(map(str, ds.evanescent_extent.values.flatten()))
#ext_vals = " ".join(map(str, ds.extent.values.flatten()))
#
#with open("evanescent_extents.txt", "a") as f:
#    f.write(f"{year}\t{ev_vals}\n")
#
#with open("extents.txt", "a") as f:
#    f.write(f"{year}\t{ext_vals}\n")

# %% [markdown]
# # Limit to region

# %%
lat = ds.latitude
lon = ds.longitude

lat_min, lat_max = -78, -77
lon_min, lon_max = 163, 167

mask_xy = ((lat >= lat_min) & (lat <= lat_max) & (lon >= lon_min) & (lon <= lon_max)).compute()

ys, xs = np.where(mask_xy.values)

ymin, ymax = ys.min(), ys.max()
xmin, xmax = xs.min(), xs.max()

ds_MMS = ds.isel(Y=slice(ymin, ymax + 1), X=slice(xmin, xmax + 1))

ds_MMS_flipped = ds_MMS.isel(X=slice(None, None, -1))

ds_MMS_flipped
# Out:
# <xarray.Dataset> Size: 891kB
# Dimensions:               (X: 119, Y: 131, time: 20)
# Coordinates:
#   * time                  (time) datetime64[ns] 160B 2000-03-01 ... 2000-12-11
# Dimensions without coordinates: X, Y
# Data variables: (12/13)
#     x                     (X) float64 952B dask.array<chunksize=(119,), meta=np.ndarray>
#     y                     (Y) float64 1kB dask.array<chunksize=(131,), meta=np.ndarray>
#     latitude              (Y, X) float32 62kB dask.array<chunksize=(131, 119), meta=np.ndarray>
#     longitude             (Y, X) float32 62kB dask.array<chunksize=(131, 119), meta=np.ndarray>
#     area                  (Y, X) float64 125kB dask.array<chunksize=(131, 119), meta=np.ndarray>
#     date_alt              (time) int32 80B dask.array<chunksize=(20,), meta=np.ndarray>
#     ...                    ...
#     formation_date        (Y, X) datetime64[ns] 125kB NaT NaT NaT ... NaT NaT
# ...

# %% [markdown]
# # Plot 15-daily maps

# %%
da = ds_MMS_flipped.Fast_Ice_Time_series.isel(time=19)

cmap = mcolors.ListedColormap(["navy", "gray", "gray", "lightgray", "cyan", "red", "orange"])
norm = mcolors.BoundaryNorm(boundaries=range(8), ncolors=cmap.N)
labels = {0: "Pack ice / ocean", 1: "Continent", 2: "Islands", 3: "Ice shelf", 4: "Fast ice", 5: "Manual fast ice edge", 6: "Auto fast ice edge"}

plt.figure(figsize=(10, 8))
plt.imshow(da, origin="lower", cmap=cmap, norm=norm)

handles = [mpatches.Patch(color=cmap(i), label=labels[i]) for i in labels]

plt.legend(handles=handles, loc="upper right", frameon=True)
plt.title(np.datetime_as_string(ds.time.values[19], unit="D"))
plt.tight_layout()
plt.show()

# %%
#for time_x in range(len(ds.time)):
#
#    da = ds_MMS_flipped.Fast_Ice_Time_series.isel(time_x)
#    
#    cmap = mcolors.ListedColormap(["navy", "gray", "gray", "lightgray", "cyan", "red", "orange"])
#    norm = mcolors.BoundaryNorm(boundaries=range(8), ncolors=cmap.N)
#    labels = {0: "Pack ice / ocean", 1: "Continent", 2: "Islands", 3: "Ice shelf", 4: "Fast ice", 5: "Manual fast ice edge", 6: "Auto fast ice edge"}
#    
#    plt.figure(figsize=(10, 8))
#    plt.imshow(da, origin="lower", cmap=cmap, norm=norm)
#    
#    handles = [mpatches.Patch(color=cmap(i), label=labels[i]) for i in labels]
#    
#    plt.legend(handles=handles, loc="upper right", frameon=True)
#    plt.title(np.datetime_as_string(ds.time.values[time_x], unit="D"))
#    plt.tight_layout()
#    plt.savefig('Figures/MMS_'+str(time_x), bbox_inches='tight')
#    plt.show()

# %% [markdown]
# # Plot surface type time series for -77.5°N, 166°E

# %%
# Extended vs. limited extent point
lat_0, lon_0 = -77.5, 166

lat = ds.latitude
lon = ds.longitude
dist2 = (lat - lat_0)**2 + (lon - lon_0)**2
iy, ix = np.unravel_index(dist2.argmin().values, dist2.shape)

ts = ds.Fast_Ice_Time_series.isel(Y=iy, X=ix)

ts.plot(marker="o")
plt.savefig('Figures/MMS_time_series_'+str(year), bbox_inches='tight')

# %% [markdown]
# # Plot ice-age map

# %%
### core site markers ###

sites = {
    "1996_SIMS": {"year": 1996, "lat": -77.648, "lon": 166.397},
    "1997_SIMS": {"year": 1997, "lat": -77.837, "lon": 166.613},
    "1999_SIMS": {"year": 1999, "lat": -77.677, "lon": 166.451},
    "2000_SIMS": {"year": 2000, "lat": -77.837, "lon": 166.613},
    "2002_SIMS_A": {"year": 2002, "lat": -77.734, "lon": 166.361},
    "2002_SIMS_B": {"year": 2002, "lat": -77.734, "lon": 166.362},
    "2002_SIMS_C": {"year": 2002, "lat": -77.734, "lon": 166.362},
    "2009_SIMS": {"year": 2009, "lat": -77.792, "lon": 166.313},
    "2010_SIMS": {"year": 2010, "lat": -77.792, "lon": 166.515},
    "2011_SIMS": {"year": 2011, "lat": -77.893, "lon": 166.740},
    "2013_SIMS": {"year": 2013, "lat": -77.795, "lon": 166.334},
    "2014_SIMS": {"year": 2014, "lat": -77.887, "lon": 166.490},
    "2018_SIMS": {"year": 2018, "lat": -77.867, "lon": 166.655},
    "2019_SIMS": {"year": 2019, "lat": -77.860, "lon": 166.766},
    "2020_SIMS": {"year": 2020, "lat": -77.888, "lon": 166.688},
    "2021_SIMS": {"year": 2021, "lat": -77.8815, "lon": 166.2328},
    "2022_SIMS": {"year": 2022, "lat": -77.8615, "lon": 166.7665},
    "2022_BLUE": {"year": 2022, "lat": None, "lon": None},
    "2022_WHITE": {"year": 2022, "lat": None, "lon": None},
    "2023_SIMS": {"year": 2023, "lat": -77.8428, "lon": 166.4863},
    "2024_SIMS": {"year": 2024, "lat": -77.8859, "lon": 166.6883},
    "2024_ARRAY_B": {"year": 2024, "lat": -77.8515, "lon": 166.4453},
    "2024_2010_SITE": {"year": 2024, "lat": -77.792, "lon": 166.515},
    "2025_SIMS": {"year": 2025, "lat": -77.8681, "lon": 166.6496},
    "2025_PT2A": {"year": 2025, "lat": -77.8415, "lon": 165.6058},
    "2025_PT2B": {"year": 2025, "lat": -77.8300, "lon": 165.6000},
}

lats = []
lons = []
for site, info in sites.items():
    if info["year"] == year and info["lat"] is not None:
        lats.append(info["lat"])
        lons.append(info["lon"])

transformer = Transformer.from_crs("EPSG:4326", "EPSG:3976", always_xy=True)
xs, ys = transformer.transform(lons, lats)

# %%
color_list = ['white', 'gray', 'lightgray', 'gold', 
              'lightcyan', 'lightskyblue', 'skyblue', 'deepskyblue', 'dodgerblue', 'cornflowerblue', 'royalblue', 'blue', 'mediumblue', 'navy',
              'slateblue', 'mediumslateblue', 'mediumpurple', 'blueviolet', 'darkviolet', 'indigo', 'purple',
              'crimson', 'firebrick', 'red', 'darkred', 'indianred', 'salmon', 'lightsalmon']

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
labels = []
for m in months:
    labels.extend([f'Early {m}', f'Mid {m}'])
handles = [mpatches.Patch(facecolor=c, edgecolor='black', label=l) for c, l in zip(color_list[4:], labels)]

fig, ax = plt.subplots(figsize=(2, 10))

ax.axis('off')
ax.legend(handles=handles, loc='center', frameon=False, ncol=1, title='Formation before')

plt.tight_layout()
plt.savefig('Figures/MMS_ice_age_legend', bbox_inches='tight')
plt.show()

# %%
selected = {1: 'Continent', 2: 'Islands', 3: 'Ice shelf'}

base = ds_MMS_flipped.Fast_Ice_Time_series.isel(time=0)
da_plot = xr.zeros_like(base)

# da.where(condition, else)
da_plot = da_plot.where(~np.isin(base, [1, 2]), 1)                                                                        # Land
da_plot = da_plot.where(base != 3, 2)                                                                                     # Ice shelf
da_plot = xr.where(ds_MMS_flipped.multi_year_fast_ice.astype(bool), 3, da_plot)                                           # Multi year fast ice   
da_plot = xr.where(~xr.ufuncs.isnan(ds_MMS_flipped.formation_date_int), ds_MMS_flipped.formation_date_int + 4, da_plot)   # First year fast ice

cmap = mcolors.ListedColormap(color_list)
norm = mcolors.BoundaryNorm(boundaries=range(len(color_list) + 1), ncolors=cmap.N)

plt.figure(figsize=(8, 10))
plt.imshow(da_plot, origin='lower', cmap=cmap, norm=norm)

### core site markers ###
x = ds_MMS_flipped.x.values
y = ds_MMS_flipped.y.values
ix = [np.abs(x - xi).argmin() for xi in xs]
iy = [np.abs(y - yi).argmin() for yi in ys]
plt.scatter(ix, iy, s=200, c="lawngreen", edgecolor="black", zorder=5)
#########################

labels = ['Land', 'Ice shelf', 'Multi-year fast ice']
handles = [mpatches.Patch(color=cmap(i), label=labels[i-1]) for i in [1, 2, 3]]
plt.legend(handles=handles, loc='upper right', frameon=True)

plt.title(str(year))
plt.tight_layout()
plt.savefig('Figures/MMS_ice_ages_'+str(year), bbox_inches='tight')
plt.show()

# %% [markdown]
# # Area within bounding box

# %%
fig = plt.figure(figsize=(10, 10))
gs = gridspec.GridSpec(1, 2, figure=fig, width_ratios=[8, 2], wspace=0., hspace=0.)
fig.subplots_adjust(hspace=-0.5)

ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])
axes = [ax1, ax2]

image_dir = 'Figures'
list_of_subplots = ['MMS_ice_ages_'+str(year)+'.png', 'MMS_ice_age_legend.png']
path_list = [os.path.join(image_dir, i) for i in list_of_subplots]

for ax, img_path in zip(axes, path_list):
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.axis('off')

plt.savefig('Figures/MMS_ice_ages_'+str(year), bbox_inches='tight')
plt.show()

# %% [markdown]
# # Plot storminess vs. formation month

# %%
df = pd.DataFrame()
df['year'] = [2000, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2023, 2024]
df['winter_si'] = [0.55, 0.99, 0.91, 0.45, 1.30, 0.77, 0.37, 1.56, 1.69, 0.86, 0.55, 1.32, 0.42, 0.88]
df['fraser_data'] = [True, True, True, True, True, True, True, True, False, False, False, False, False, False]
df['formation_month'] = ['April', 'April', 'June', 'April', 'April', 'April', 'March', 'April', 'July', 'May', 'May', 'September', 'April', 'September']
df['formation_month_num'] = [4, 4, 6, 4, 4, 4, 3, 4, 7, 5, 5, 9, 4, 9]
df['area'] = [2277, 2379, 2445, 2331, 2475, 2306, 2909, 2318, 2613, 2123, 3045, 2335, 3045, 2599]
df = df.sort_values(by='winter_si')
df_a = df
df_a
# Out:
#     year  winter_si  fraser_data formation_month  formation_month_num  area
# 6   2016       0.37         True           March                    3  2909
# 12  2023       0.42        False           April                    4  3045
# 3   2013       0.45         True           April                    4  2331
# 0   2000       0.55         True           April                    4  2277
# 10  2021       0.55        False             May                    5  3045
# 5   2015       0.77         True           April                    4  2306
# 9   2020       0.86        False             May                    5  2123
# 13  2024       0.88        False       September                    9  2599
# 2   2012       0.91         True            June                    6  2445
# 1   2011       0.99         True           April                    4  2379
# 4   2014       1.30         True           April                    4  2475
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 6))

winter_colors = np.where(df_a["fraser_data"], "gray", "gold")
month_colors = {
    3: "powderblue",
    4: "steelblue",
    5: "royalblue",
    6: "darkblue",
    7: "purple",
    8: "orchid",
    9: "hotpink"}
formation_colors = df_a["formation_month_num"].map(month_colors)

x = range(len(df_a))
ax.bar(x, df_a["winter_si"], color=winter_colors)
ax.bar(x, -0.001*(df_a["area"]-2000), color=formation_colors)

ax.axhline(0)

ax.set_xticks(x)
ax.set_xticklabels(df_a["year"], rotation=45)
ax.set_ylabel("December area in km² (down) / mean winter storm index (up)", fontsize=12)

# tick labels
ax.set_yticks([-1.5, -1, -0.5, 0, 0.5, 1, 1.5])
ax.set_yticklabels(["3500", "3000", "2500", "0", "0.5", "1", "1.5"])

# legend
legend_elements = [
    # winter_si
    mpatches.Patch(facecolor="gray", label="2000, 2011 - 2017"),
    mpatches.Patch(facecolor="gold", label="2019 - 2024"),
    # formation month
    mpatches.Patch(facecolor="powderblue", label="March"),
    mpatches.Patch(facecolor="steelblue", label="April"),
    mpatches.Patch(facecolor="royalblue", label="May"),
    mpatches.Patch(facecolor="darkblue", label="June"),
    mpatches.Patch(facecolor="purple", label="July"),
    mpatches.Patch(facecolor="orchid", label="August"),
    mpatches.Patch(facecolor="hotpink", label="September"),]
ax.legend(handles=legend_elements, loc=0, frameon=False, fontsize=10)

plt.tight_layout()
plt.savefig('Figures/si_connection_1', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

winter_colors = np.where(df_a["fraser_data"], "gray", "gold")
month_colors = {
    3: "powderblue",
    4: "steelblue",
    5: "royalblue",
    6: "darkblue",
    7: "purple",
    8: "orchid",
    9: "hotpink"}
formation_colors = df_a["formation_month_num"].map(month_colors)

x = range(len(df_a))
ax.bar(x, df_a["winter_si"], color=winter_colors)
ax.bar(x, -0.5*(df_a["formation_month_num"]-2), color=formation_colors)

ax.axhline(0)

ax.set_xticks(x)
ax.set_xticklabels(df_a["year"], rotation=45)
ax.set_ylabel("formation month (down) / mean winter storm index (up)", fontsize=12)

# tick labels
ax.set_yticks([-3.5, -3, -2.5, -2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5])
ax.set_yticklabels(["Sep", "Aug", "Jul", "Jun", "May", "Apr", "Mar", "0", "0.5", "1", "1.5"])

# legend
legend_elements = [
    # winter_si
    mpatches.Patch(facecolor="gray", label="Fraser data"),
    mpatches.Patch(facecolor="gold", label="2019 - 2024"),
    # formation month
    mpatches.Patch(facecolor="powderblue", label="March"),
    mpatches.Patch(facecolor="steelblue", label="April"),
    mpatches.Patch(facecolor="royalblue", label="May"),
    mpatches.Patch(facecolor="darkblue", label="June"),
    mpatches.Patch(facecolor="purple", label="July"),
    mpatches.Patch(facecolor="orchid", label="August"),
    mpatches.Patch(facecolor="hotpink", label="September"),]
ax.legend(handles=legend_elements, loc="lower left", frameon=False, fontsize=10)

# years of expansive extent
arrow_years = [2016, 2023, 2021, 2000]
year_to_x = dict(zip(df_a["year"], x))
for y in arrow_years:
    xi = year_to_x[y]
    ax.annotate("", xy=(xi, 0.7), xytext=(xi, 1.4), arrowprops=dict(arrowstyle="->", color="red", lw=3))
ax.text( 0.02, 0.95, "expansive fast-ice extent", transform=ax.transAxes, fontsize=14, color="red", va="top", ha="left",
         bbox=dict(boxstyle="round,pad=0.3",facecolor="white",edgecolor="red",alpha=0.9))

plt.tight_layout()
plt.savefig('Figures/si_connection', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Plot extent climatology time series with extent and storm index of the year

# %%
# Storm index from si_file.csv
df_si = pd.read_csv('si_file.csv')
df_si = df_si[['DateTime', 'SB_SI']]
df_si["DateTime"] = pd.to_datetime(df_si["DateTime"], format="%Y-%m-%d")
df_si.index = df_si['DateTime']
df_si['month_day'] = df_si.index.strftime('%m-%d')
df_si['year'] = df_si.index.year
df_si = pd.concat([df_si.pivot(index='month_day', columns='year', values='SB_SI').add_prefix('SI')], axis=1)

# %%
# Evanescent fast-ice extents from evanescent_extents.txt
records = []
with open("evanescent_extents.txt") as f:
    for line in f:
        year_i, values = line.split("\t", 1)
        year_i = int(year_i)
        nums = np.fromstring(values.strip("[]\n"), sep=" ")

        for i, val in enumerate(nums):
            month = i // 2 + 1
            day = 1 if i % 2 == 0 else 15
            records.append({"DateTime": pd.Timestamp(year=year_i, month=month, day=day), "evanescent_extent": val})
df_ext_ev = pd.DataFrame(records)
df_ext_ev["DateTime"] = pd.to_datetime(df_ext_ev["DateTime"])
df_ext_ev.index = df_ext_ev['DateTime']
df_ext_ev['month_day'] = df_ext_ev.index.strftime('%m-%d')
df_ext_ev['year'] = df_ext_ev.index.year
df_ext_ev = pd.concat([df_ext_ev.pivot(index='month_day', columns='year', values='evanescent_extent').add_prefix('EV')], axis=1)
df_ext_ev = df_ext_ev.replace(-1, np.nan)

# %%
# Fast-ice extents from extents.txt
records = []
with open("extents.txt") as f:
    for line in f:
        year_i, values = line.split("\t", 1)
        year_i = int(year_i)
        nums = np.fromstring(values.strip("[]\n"), sep=" ")

        for i, val in enumerate(nums):
            month = i // 2 + 1
            day = 1 if i % 2 == 0 else 15
            records.append({"DateTime": pd.Timestamp(year=year_i, month=month, day=day), "extent": val})
df_ext = pd.DataFrame(records)
df_ext["DateTime"] = pd.to_datetime(df_ext["DateTime"])
df_ext.index = df_ext['DateTime']
df_ext['month_day'] = df_ext.index.strftime('%m-%d')
df_ext['year'] = df_ext.index.year
df_ext = pd.concat([df_ext.pivot(index='month_day', columns='year', values='extent').add_prefix('EX')], axis=1)
df_ext = df_ext.replace(-1, np.nan)

# Extent climatology
exclude_cols = [f'EX{year}' for year in range(2001, 2011)]    # Iceberg years
df_ext["clim"] = df_ext.drop(columns=exclude_cols).mean(axis=1)
print(df_ext['clim'].iloc[-1])
# Out:
# 2505.497698262505

# %%
df = df_si.merge(df_ext_ev, on="month_day", how='outer')
df = df.merge(df_ext, on="month_day", how='outer')
#df = df.interpolate(method='bfill', limit=20)
df = df.interpolate(method='linear', limit=20)
df
# Out:
# year       SI1964    SI1965    SI1966    SI1967    SI1968    SI1969    SI1970  \
# month_day
# 01-01         NaN  0.000000  0.000000  0.000000  0.001143  0.000000  0.000000
# 01-02         NaN  0.000000  0.000000  0.000000  0.001143  0.000000  0.140150
# 01-03         NaN  0.000000  0.000000  0.000000  0.001143  0.000000  0.219106
# 01-04         NaN  0.000000  0.001888  0.000000  0.000000  0.000000  0.219106
# 01-05         NaN  0.078931  0.001888  0.000000  0.025924  0.000000  0.078956
# ...           ...       ...       ...       ...       ...       ...       ...
# 12-27         0.0  0.000000  0.000000  0.000000  0.000000  0.169147  0.000000
# 12-28         0.0  0.000000  0.000000  0.011207  0.000000  0.000000  0.000000
# 12-29         0.0  0.000000  0.000000  0.011207  0.000000  0.000000  0.000000
# 12-30         0.0  0.000000  0.000000  0.011207  0.000000  0.000000  0.000000
# 12-31         0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
year = 2024

# %%
# Compute formation date
#threshold_value = df['clim'].iloc[-1]*0.5
threshold_value = df['EX'+str(year)].iloc[-1]*0.5
exceeds_threshold = df.index[df['EX'+str(year)] > (threshold_value)]
if not exceeds_threshold.empty:
    result_day = exceeds_threshold[0]
    print(f"The fast-ice extent first rises above {threshold_value} on: {result_day}")
else:
    print(f"The fast-ice extent never reaches {threshold_value} in this dataset.")
# Out:
# The fast-ice extent first rises above 1299.2812395 on: 08-19

# %%
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [df.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

fig, ax1 = plt.subplots(figsize=(10, 4))

ax1.plot(df.index, df["clim"], label="Climatology", lw=2)
ax1.plot(df.index, df["EX"+str(year)], label="This year's extent")
ax1.set_ylabel("Extent", fontsize=14)

ax2 = ax1.twinx()
ax2.plot(df.index, df["SI"+str(year)], label="Storm index", alpha=0.6)
ax2.set_ylabel("Storm index", fontsize=14)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="upper left")
ax1.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)
ax1.set_xticks(ticks=month_start_positions, labels=month_start_labels, rotation=45)
ax1.set_xlim(('01-01', '12-31'))
ax1.set_ylim((0,3100))
ax2.set_ylim((-0.5,17))
ax1.set_title(f"{year}", fontsize=18)
plt.tight_layout()

plt.savefig('Figures/si_1_'+str(year)+'_linearinterp', bbox_inches='tight')
plt.show()

# %%
'''
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [df.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

fig, ax1 = plt.subplots(figsize=(10, 4))

ax1.plot(df.index, df["clim"], label="Climatology", lw=2)
ax1.plot(df.index, df["EX"+str(year)], label="This year's extent")
ax1.plot(df.index, df["EV"+str(year)], label="This year's evanescent extent")
ax1.set_ylabel("Extent", fontsize=14)

ax2 = ax1.twinx()
ax2.plot(df.index, df["SI"+str(year)], label="Storm index", alpha=0.6)
ax2.set_ylabel("Storm index", fontsize=14)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="upper left")
ax1.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)
ax1.set_xticks(ticks=month_start_positions, labels=month_start_labels, rotation=45)
ax1.set_xlim(('01-01', '12-31'))
ax1.set_ylim((0,3050))
ax2.set_ylim((-0.5,17))
ax1.set_title(f"{year}", fontsize=18)
plt.tight_layout()

plt.savefig('Figures/si_'+str(year)+'_linearinterp', bbox_inches='tight')
plt.show()
'''
# Out:
# '\n# format x-axis\nmonth_starts = [f\'{m}-01\' for m in [\'01\', \'02\', \'03\', \'04\', \'05\', \'06\', \'07\', \'08\', \'09\', \'10\', \'11\', \'12\']]\nmonth_start_positions = [df.index.get_loc(month_start) for month_start in month_starts]\nmonth_start_labels = [\'Jan\', \'Feb\', \'Mar\', \'Apr\', \'May\', \'Jun\', \'Jul\', \'Aug\', \'Sep\', \'Oct\', \'Nov\', \'Dec\']\n\nfig, ax1 = plt.subplots(figsize=(10, 4))\n\nax1.plot(df.index, df["clim"], label="Climatology", lw=2)\nax1.plot(df.index, df["EX"+str(year)], label="This year\'s extent")\nax1.plot(df.index, df["EV"+str(year)], label="This year\'s evanescent extent")\nax1.set_ylabel("Extent", fontsize=14)\n\nax2 = ax1.twinx()\nax2.plot(df.index, df["SI"+str(year)], label="Storm index", alpha=0.6)\nax2.set_ylabel("Storm index", fontsize=14)\n\nlines1, labels1 = ax1.get_legend_handles_labels()\nlines2, labels2 = ax2.get_legend_handles_labels()\nax1.legend(lines1 + lines2, labels1 + labels2, loc="upper left")\nax1.tick_params(labels
# ...

# %%
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [df.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# add 67% dots
def add_80pct_marker(ax, x, y, clim_max, **kwargs):
    y80 = 0.67 * min(y.max(), clim_max)
    i80 = (y >= y80).idxmax()
    x80 = x.get_loc(i80)

    ax.plot(x80, y.loc[i80], marker='o', **kwargs)
    ax.vlines(x80, 0, y.loc[i80], linestyles='dashed', alpha=0.5, **kwargs)

fig, ax1 = plt.subplots(figsize=(10, 6))

clim_max = df["clim"].max()
ax1.plot(df.index, df["clim"], label="Climatology", lw=3, color='red')
add_80pct_marker(ax1, df.index, df["clim"], clim_max, color='red')
years = [2000, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2023, 2024]
#tol = ["#4477AA", "#66CCEE", "#228833", "#CCBB44", "#EE6677", "#AA3377", "#BBBBBB", "#000000", "#77AADD", "#99DDFF", "#44BB99", "#DDCC77", "#CC6677", "#882255"]
#cmap = ListedColormap(tol)
cmap = cc.cm.glasbey
for i, year_idx in enumerate(years):
    col = "EX" + str(year_idx)
    color = cmap(i)
    line, = ax1.plot(df.index, df[col], label=year_idx, color=color)
    add_80pct_marker(ax1, df.index, df[col], clim_max, color=color)

ax1.set_ylabel("Extent (km²)", fontsize=14)
lines1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(lines1, labels1, loc="upper left")
ax1.tick_params(labelsize=12)
ax1.set_xticks(ticks=month_start_positions, labels=month_start_labels, rotation=45)
ax1.set_xlim(('01-01', '12-31'))
ax1.set_ylim((0,3100))
ax1.set_title('all years', fontsize=18)
plt.tight_layout()

plt.savefig('Figures/si_all_at_once_linearinterp', bbox_inches='tight')
plt.show()

# %%
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [df.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# add 67% dots
def add_80pct_marker(ax, x, y, clim_max, **kwargs):
    y80 = 0.67 * min(y.max(), clim_max)
    i80 = (y >= y80).idxmax()
    x80 = x.get_loc(i80)

    ax.plot(x80, y.loc[i80], marker='o', **kwargs)
    ax.vlines(x80, 0, y.loc[i80], linestyles='dashed', alpha=0.5, **kwargs)

fig, ax1 = plt.subplots(figsize=(10, 6))

clim_max = df["clim"].max()
ax1.plot(df.index, df["clim"], label="Climatology", lw=3, color='red')
add_80pct_marker(ax1, df.index, df["clim"], clim_max, color='red')
years = [2000, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2023, 2024]
for i, year_idx in enumerate(years):
    if year_idx in [2000, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2021, 2022, 2023, 2024]:
        col = "EX" + str(year_idx)
        color = cmap(i)
        line, = ax1.plot(df.index, df[col], label=year_idx, color='lightgrey')
        add_80pct_marker(ax1, df.index, df[col], clim_max, color=line.get_color())
    else:
        col = "EX" + str(year_idx)
        color = cmap(i)
        line, = ax1.plot(df.index, df[col], label=year_idx)
        add_80pct_marker(ax1, df.index, df[col], clim_max, color=line.get_color())


ax1.set_ylabel("Extent (km²)", fontsize=14)
lines1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(lines1, labels1, loc="upper left")
ax1.tick_params(labelsize=12)
ax1.set_xticks(ticks=month_start_positions, labels=month_start_labels, rotation=45)
ax1.set_xlim(('01-01', '12-31'))
ax1.set_ylim((0,3100))
ax1.set_title('particularly low final extent', fontsize=18)
plt.tight_layout()

#plt.savefig('Figures/si_all_at_once_linearinterp', bbox_inches='tight')
plt.show()

# %%
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [df.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# add 67% dots
def add_80pct_marker(ax, x, y, clim_max, **kwargs):
    y80 = 0.67 * min(y.max(), clim_max)
    i80 = (y >= y80).idxmax()
    x80 = x.get_loc(i80)

    ax.plot(x80, y.loc[i80], marker='o', **kwargs)
    ax.vlines(x80, 0, y.loc[i80], linestyles='dashed', alpha=0.5, **kwargs)

fig, ax1 = plt.subplots(figsize=(10, 6))

clim_max = df["clim"].max()
ax1.plot(df.index, df["clim"], label="Climatology", lw=3, color='red')
add_80pct_marker(ax1, df.index, df["clim"], clim_max, color='red')

years = [2000, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2023, 2024]
for i, year_idx in enumerate(years):
    if year_idx in [2000, 2011, 2013, 2014, 2015, 2016, 2017, 2020, 2021, 2023]:
        col = "EX" + str(year_idx)
        color = cmap(i)
        line, = ax1.plot(df.index, df[col], label=year_idx, color='lightgrey')
        add_80pct_marker(ax1, df.index, df[col], clim_max, color=line.get_color())
    else:
        col = "EX" + str(year_idx)
        color = cmap(i)
        line, = ax1.plot(df.index, df[col], label=year_idx)
        add_80pct_marker(ax1, df.index, df[col], clim_max, color=line.get_color())

ax1.set_ylabel("Extent (km²)", fontsize=14)
lines1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(lines1, labels1, loc="upper left")
ax1.tick_params(labelsize=12)
ax1.set_xticks(ticks=month_start_positions, labels=month_start_labels, rotation=45)
ax1.set_xlim(('01-01', '12-31'))
ax1.set_ylim((0,3100))
ax1.set_title('late formation', fontsize=18)
plt.tight_layout()

#plt.savefig('Figures/si_all_at_once_linearinterp', bbox_inches='tight')
plt.show()

# %%
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [df.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# add 67% dots
def add_80pct_marker(ax, x, y, clim_max, **kwargs):
    y80 = 0.67 * min(y.max(), clim_max)
    i80 = (y >= y80).idxmax()
    x80 = x.get_loc(i80)

    ax.plot(x80, y.loc[i80], marker='o', **kwargs)
    ax.vlines(x80, 0, y.loc[i80], linestyles='dashed', alpha=0.5, **kwargs)

fig, ax1 = plt.subplots(figsize=(10, 6))

clim_max = df["clim"].max()
ax1.plot(df.index, df["clim"], label="Climatology", lw=3, color='red')
add_80pct_marker(ax1, df.index, df["clim"], clim_max, color='red')

years = [2000, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2023, 2024]
for i, year_idx in enumerate(years):
    if year_idx in [2000, 2011, 2012, 2013, 2014, 2017, 2019, 2020, 2022, 2024]:
        col = "EX" + str(year_idx)
        color = cmap(i)
        line, = ax1.plot(df.index, df[col], label=year_idx, color='lightgrey')
        add_80pct_marker(ax1, df.index, df[col], clim_max, color=line.get_color())
    else:
        col = "EX" + str(year_idx)
        color = cmap(i)
        line, = ax1.plot(df.index, df[col], label=year_idx)
        add_80pct_marker(ax1, df.index, df[col], clim_max, color=line.get_color())

ax1.set_ylabel("Extent (km²)", fontsize=14)
lines1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(lines1, labels1, loc="upper left")
ax1.tick_params(labelsize=12)
ax1.set_xticks(ticks=month_start_positions, labels=month_start_labels, rotation=45)
ax1.set_xlim(('01-01', '12-31'))
ax1.set_ylim((0,3100))
ax1.set_title('early formation or large extent', fontsize=18)
plt.tight_layout()

#plt.savefig('Figures/si_all_at_once_linearinterp', bbox_inches='tight')
plt.show()

# %%
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [df.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# add 67% dots
def add_80pct_marker(ax, x, y, clim_max, **kwargs):
    y80 = 0.67 * min(y.max(), clim_max)
    i80 = (y >= y80).idxmax()
    x80 = x.get_loc(i80)

    ax.plot(x80, y.loc[i80], marker='o', **kwargs)
    ax.vlines(x80, 0, y.loc[i80], linestyles='dashed', alpha=0.5, **kwargs)

fig, ax1 = plt.subplots(figsize=(10, 6))

clim_max = df["clim"].max()
ax1.plot(df.index, df["clim"], label="Climatology", lw=3, color='red')
add_80pct_marker(ax1, df.index, df["clim"], clim_max, color='red')
years = [2000, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2023, 2024]
winter_si_by_year = df_a.set_index("year")["winter_si"]
cmap = plt.get_cmap("cool")
norm = Normalize(vmin=winter_si_by_year.min(), vmax=winter_si_by_year.max())
sm = ScalarMappable(norm=norm, cmap=cmap)
for year_idx in years:
    col = "EX" + str(year_idx)
    si = winter_si_by_year.loc[year_idx]
    color = cmap(norm(si))
    line, = ax1.plot(df.index, df[col], label=year_idx, color=color)
    add_80pct_marker(ax1, df.index, df[col], clim_max, color=line.get_color())

cbar = plt.colorbar(sm, ax=ax1)
cbar.set_label("Winter storminess")

ax1.set_ylabel("Extent (km²)", fontsize=14)
lines1, labels1 = ax1.get_legend_handles_labels()
#ax1.legend(lines1, labels1, loc="upper left")
ax1.tick_params(labelsize=12)
ax1.set_xticks(ticks=month_start_positions, labels=month_start_labels, rotation=45)
ax1.set_xlim(('01-01', '12-31'))
ax1.set_ylim((0,3100))
ax1.set_title('all years by storminess', fontsize=18)
plt.tight_layout()

#plt.savefig('Figures/si_all_at_once_linearinterp', bbox_inches='tight')
plt.show()
