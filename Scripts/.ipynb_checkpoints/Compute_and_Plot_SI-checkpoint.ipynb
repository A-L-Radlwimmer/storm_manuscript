# %% [markdown]
# # Storm Indices

# %%
import storm_indices as si

import numpy as np
import pandas as pd
import tqdm
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.patches as patches
import seaborn as sns
import glob as gl
from datetime import datetime, date, time, timedelta
import calendar
import pymannkendall as mk
from scipy.optimize import curve_fit
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Choose Station

# %%
station_name = 'ScottBase'

#station_name = 'Lettau'
#station_name = 'Margaret'
#station_name = 'Gill'
#station_name = 'Schwerdtfeger'
#station_name = 'Marilyn'
#station_name = 'Ferrell'
#station_name = 'LaurieII'
#station_name = 'Arelis'
#station_name = 'MarblePoint'
#station_name = 'Manuela'
#station_name = 'Alessandra'
#station_name = 'Silvia'

# %% [markdown]
# ### Read in Temperature and Pressure Data

# %%
if station_name == 'ScottBase':
    # SCOTT BASE
    t_column_name = 'Mean Temperature [Deg C]'
    p_column_name = 'Mean sea level pressure [Hpa]'
    TP = pd.read_csv('../Data/scottbase/scottbase.csv')
    TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
    TP.index = TP['DateTime']
    del TP['DateTime']
elif station_name in ['Lettau', 'Margaret', 'Gill', 'Schwerdtfeger', 'Marilyn', 'Ferrell', 'LaurieII', 'MarblePoint', 'Manuela']:
    # AMRC AWS
    if station_name == 'MarblePoint':
        TP = pd.read_csv('../Data/marblePoint/marblePoint.csv')
    elif station_name == 'Manuela':
        TP = pd.read_csv('../Data/manuela/manuela.csv')
    elif station_name == 'Ferrell':
        TP = pd.read_csv('../Data/ferrell/ferrell.csv')
    elif station_name == 'Margaret':
        TP = pd.read_csv('../Data/margaret/margaret.csv')
    elif station_name == 'Schwerdtfeger':
        TP = pd.read_csv('../Data/schwerdtfeger/schwerdtfeger.csv')
    elif station_name == 'Marilyn':
        TP = pd.read_csv('../Data/marilyn/marilyn.csv')
    elif station_name == 'Gill':
        TP = pd.read_csv('../Data/gill/gill.csv')
    elif station_name == 'LaurieII':
        TP = pd.read_csv('../Data/laurie2/laurie2.csv')
    elif station_name == 'Lettau':
        TP = pd.read_csv('../Data/lettau/lettau.csv')
    t_column_name = 'temperature'
    p_column_name = 'pressure'
    TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
    TP.index = TP['DateTime']
    del TP['DateTime']
else:
    # WANG et al, 2022
    if station_name == 'Arelis':
        TP = pd.read_csv('../Data/arelis/arelis.csv')
    elif station_name == 'Alessandra':
        TP = pd.read_csv('../Data/alessandra/alessandra.csv')
    elif station_name == 'Silvia':
        TP = pd.read_csv('../Data/silvia/silvia.csv')
    t_column_name = 'temperature_C'
    p_column_name = 'pressure_hPa'
    TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
    TP.index = TP['DateTime']
    del TP['DateTime']

# %%
TP = TP[[t_column_name, p_column_name]]
TP = TP[~TP.index.isna()]
TP
# Out:
#             Mean Temperature [Deg C]  Mean sea level pressure [Hpa]
# DateTime
# 1964-09-30                       NaN                         1005.0
# 1964-10-01                     -24.6                          997.6
# 1964-10-02                     -25.8                          997.4
# 1964-10-03                     -28.3                          989.1
# 1964-10-04                     -26.2                          976.2
# ...                              ...                            ...
# 2025-10-23                     -22.4                            NaN
# 2025-10-24                     -22.6                            NaN
# 2025-10-25                     -16.0                            NaN
# 2025-10-26                     -12.9                            NaN
# 2025-10-27                     -12.8                            NaN
#
# [22306 rows x 2 columns]

# %% [markdown]
# ### Get Start and End Year

# %%
#start_year = int(np.min(TP.index.year))
start_year = 1964
#end_year = int(np.max(TP.index.year))
end_year = 2024
print(start_year, end_year)
years = np.array([int(i) for i in range(start_year, end_year+1)], dtype=int)
full_index = pd.date_range(start=str(start_year)+"-01-01", end=str(end_year)+"-12-31", freq="D")
TP = TP.reindex(full_index)
# Out:
# 1964 2024

# %% [markdown]
# ### Compute Storm Index

# %%
TP = si.compute_si(TP, t_column_name, p_column_name, 'SI')
TP
# Out:
#             Mean Temperature [Deg C]  Mean sea level pressure [Hpa]   SI
# 1964-01-01                       NaN                            NaN  NaN
# 1964-01-02                       NaN                            NaN  NaN
# 1964-01-03                       NaN                            NaN  NaN
# 1964-01-04                       NaN                            NaN  NaN
# 1964-01-05                       NaN                            NaN  NaN
# ...                              ...                            ...  ...
# 2024-12-27                      -3.4                          989.1  0.0
# 2024-12-28                      -4.7                          993.9  0.0
# 2024-12-29                      -2.9                          989.5  0.0
# 2024-12-30                      -1.2                          985.8  0.0
# 2024-12-31                      -0.9                          989.3  0.0
#
# [22281 rows x 3 columns]

# %% [markdown]
# ### How many storms are stormier than average?

# %%
# Fraction of strong storm days in all storm days
fraction_of_strong_storms = (TP['SI'] > 1).sum() / (TP['SI'] > 0).sum()
# Fraction of strong storm days in all days
fraction_of_strong_storms_of_all_days = (TP['SI'] > 1).sum() / TP['SI'].notna().sum()
# How many of the strong storm days happen in winter?
TP_copy = TP.copy()
#TP_copy = TP.loc['1965-01-01':'1994-12-31'] # optionally limit to certain time ('1965-01-01':'1994-12-31' or '1995-01-01':'2024-12-31')
si_above_1 = TP_copy['SI'] > 1
days_with_si = TP_copy[si_above_1]
winter_months = [4, 5, 6, 7, 8, 9]
winter_days_with_si = days_with_si.index.month.isin(winter_months).sum()
total_days_with_si = si_above_1.sum()
winter_fraction_of_strong_storm_days = winter_days_with_si / total_days_with_si if total_days_with_si > 0 else float('nan')

print(fraction_of_strong_storms)
print(fraction_of_strong_storms_of_all_days)
print(winter_fraction_of_strong_storm_days)
# Out:
# 0.2877948049125095
# 0.12052250694096764
# 0.7496223564954683

# %% [markdown]
# ### How many storms that are stormier than average are there per year? And what is their average storminess?

# %%
# max. 1/2 of data missing
min_days = 183 #365 days in a year
min_days_winter = 93 #185 days in austral winter
min_days_summer = 90 #180 days in austral summer

# %%
TP_summer = TP[TP.index.month.isin([1, 2, 3, 10, 11, 12])]
TP_winter = TP[TP.index.month.isin([4, 5, 6, 7, 8, 9])]
entries = TP['SI'].groupby(TP.index.year).count()
entries_summer = TP_summer['SI'].groupby(TP_summer.index.year).count()
entries_winter = TP_winter['SI'].groupby(TP_winter.index.year).count()

count = (TP['SI'] > 1).groupby(TP.index.year).sum().to_frame(name='count')
count.loc[entries < min_days, 'count'] = np.nan
count_summer = (TP_summer['SI'] > 1).groupby(TP_summer.index.year).sum().to_frame(name='count summer')
count_summer.loc[entries_summer < min_days_summer, 'count summer'] = np.nan
count_winter = (TP_winter['SI'] > 1).groupby(TP_winter.index.year).sum().to_frame(name='count winter')
count_winter.loc[entries_winter < min_days_winter, 'count winter'] = np.nan
mean = TP[TP['SI'] > 1].groupby(TP[TP['SI'] > 1].index.year)['SI'].mean().to_frame(name='mean')
mean.loc[entries < min_days, 'mean'] = np.nan
mean_summer = TP_summer[TP_summer['SI'] > 1].groupby(TP_summer[TP_summer['SI'] > 1].index.year)['SI'].mean().to_frame(name='mean summer')
mean_summer.loc[entries_summer < min_days_summer, 'mean summer'] = np.nan
mean_winter = TP_winter[TP_winter['SI'] > 1].groupby(TP_winter[TP_winter['SI'] > 1].index.year)['SI'].mean().to_frame(name='mean winter')
mean_winter.loc[entries_winter < min_days_winter, 'mean winter'] = np.nan
strong_storms = pd.concat([count, count_summer, count_winter, mean, mean_summer, mean_winter], axis=1)
strong_storms
# Out:
#       count  count summer  count winter      mean  mean summer  mean winter
# 1964    NaN           5.0           NaN       NaN     1.099610          NaN
# 1965   29.0          15.0          14.0  2.065209     2.611931     1.479435
# 1966   46.0          16.0          30.0  2.422538     1.830211     2.738445
# 1967   49.0           4.0          45.0  3.341474     1.258557     3.526622
# 1968   29.0           4.0          25.0  3.077722     1.577988     3.317680
# ...     ...           ...           ...       ...          ...          ...
# 2020   58.0          17.0          41.0  2.889693     2.024204     3.248554
# 2021   29.0           0.0          29.0  2.898027          NaN     2.898027
# 2022   93.0          28.0          65.0  3.059077     1.968496     3.528865
# 2023   41.0          17.0          24.0  2.351995     1.584330     2.895758
# 2024   63.0          19.0          44.0  2.790768     1.986705     3.137977
#
# [61 rows x 6 columns]

# %% [markdown]
# ### Compute Annual and Seasonal Sums of Storm Index

# %%
TP['year'] = TP.index.year
TP_winter = TP.copy()
TP_winter['month'] = TP_winter.index.month
TP_winter['winter'] = np.where(TP_winter['month'].isin([4, 5, 6, 7, 8, 9]), True, False)
TP_winter = TP_winter[TP_winter['winter'] == True]
TP_summer = TP.copy()
TP_summer['month'] = TP_summer.index.month
TP_summer['summer'] = np.where(TP_summer['month'].isin([1, 2, 3, 10, 11, 12]), True, False)
TP_summer = TP_summer[TP_summer['summer'] == True]

# sum up and divide by the count of non-nan-values per year/winter for an annual/seasonal storm index with a per-day unit
number_of_non_nan_days = TP.groupby(['year'])['SI'].count()
annual = TP.groupby(['year'])['SI'].sum() / number_of_non_nan_days
number_of_non_nan_days_winter = TP_winter.groupby(['year'])['SI'].count()
seasonal = TP_winter.groupby(['year'])['SI'].sum() / number_of_non_nan_days_winter
number_of_non_nan_days_summer = TP_summer.groupby(['year'])['SI'].count()
seasonal_summer = TP_summer.groupby(['year'])['SI'].sum() / number_of_non_nan_days_summer

del TP['year']

# handle data gaps
full_years = pd.Index(range(start_year, end_year + 1), name='year')
annual = annual.reindex(full_years)
seasonal = seasonal.reindex(full_years)
seasonal_summer = seasonal_summer.reindex(full_years)
invalid_years = number_of_non_nan_days[number_of_non_nan_days < min_days].index
invalid_years_winter = number_of_non_nan_days_winter[number_of_non_nan_days_winter < min_days_winter].index
invalid_years_summer = number_of_non_nan_days_summer[number_of_non_nan_days_summer < min_days_summer].index
annual.loc[invalid_years] = np.nan
seasonal.loc[invalid_years_winter] = np.nan
seasonal_summer.loc[invalid_years_summer] = np.nan

# %%
ASI = pd.DataFrame({'all':annual.values, 'winter':seasonal.values, 'summer':seasonal_summer.values}, index=full_years)
ASI
# Out:
#            all    winter    summer
# year
# 1964       NaN       NaN  0.108002
# 1965  0.240765  0.195925  0.285852
# 1966  0.402417  0.580027  0.222844
# 1967  0.520706  0.933815  0.105327
# 1968  0.296826  0.506366  0.087286
# ...        ...       ...       ...
# 2020  0.574703  0.860964  0.288442
# 2021  0.318855  0.548679  0.087769
# 2022  0.850187  1.316622  0.381189
# 2023  0.362095  0.421941  0.301920
# 2024  0.608409  0.878788  0.338030
#
# [61 rows x 3 columns]

# %%
for col in ['all', 'winter', 'summer']:
    clean_series = ASI[col].dropna()
    N = len(clean_series)
    weighted_lags_sum = 0
    for i in range(1, N):
        r = clean_series.autocorr(lag=i)
        if not np.isnan(r):
            weighted_lags_sum += (1 - i / N) * r
        matt_corr_length = 1 + 2 * weighted_lags_sum
    print(matt_corr_length)
# Out:
# 7.200838577934538
# 6.034736152362897
# 1.4426071580064805

# %% [markdown]
# ### Prepare Second Dataframe with years split into columns (helpful for plotting)

# %%
df = TP.copy()

df['month_day'] = df.index.strftime('%m-%d')
df['year'] = df.index.year

# Create a new DataFrame with desired structure
TP_plot = pd.concat([
    df.pivot(index='month_day', columns='year', values=t_column_name).add_prefix('T'),
    df.pivot(index='month_day', columns='year', values=p_column_name).add_prefix('P'),
    df.pivot(index='month_day', columns='year', values='SI').add_prefix('SI')
], axis=1)

TP_plot
# Out:
# year       T1964  T1965  T1966  T1967  T1968  T1969  T1970  T1971  T1972  \
# month_day
# 01-01        NaN   -4.5   -1.8   -2.0   -1.3   -1.7   -1.1    0.4   -2.0
# 01-02        NaN   -4.4   -2.4   -2.3   -3.2   -6.2   -2.1    1.3   -2.7
# 01-03        NaN   -2.0   -3.7   -3.6   -4.6   -6.4   -4.2    1.5   -1.4
# 01-04        NaN   -7.3   -4.2    0.2   -2.7   -6.1   -4.0    1.4   -1.6
# 01-05        NaN   -3.8   -3.9    1.3   -2.7   -7.7   -2.0   -0.5   -6.5
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 12-27       -3.9   -2.4   -2.8   -3.0   -2.0   -2.9   -6.0   -3.7   -3.3
# 12-28       -0.5   -3.6   -5.0   -8.1   -0.5   -1.3   -8.3   -6.5   -4.9
# 12-29       -0.3   -0.7   -5.4   -3.6   -2.0   -0.4   -4.8   -4.5   -6.0
# 12-30       -0.3   -0.5   -1.4   -3.6   -1.4   -0.2   -3.0   -1.0   -4.4
# 12-31       -2.0   -2.3   -2.8   -3.1   -1.1    0.0   -2.0   -2.2   -3.8
#
# year       T1973  ...    SI2015    SI2016    SI2017    SI2018    SI2019  \
# ...

# %% [markdown]
# ### Compute Center of Storminess

# %%
invalid_years = {}
CoS = []                              # DoY of Center of Storminess per year.
a = np.arange(len(TP_plot))
for i in years:
    weights = TP_plot['SI'+str(i)]
    masked_weights = np.ma.MaskedArray(weights, mask=np.isnan(weights))
    if masked_weights.count() < 335:
        CoS.append(np.nan)
        invalid_years[i] = True
    else:
        center = np.ma.average(a, weights=masked_weights)
        CoS.append(center)
        invalid_years[i] = False
CoS_df = pd.DataFrame({'years': years, 'cos': CoS})
print(CoS_df.cos.mean())
print(CoS_df.cos.std())
CoS_df[50:]
# Out:
# 183.8535523714573
# 22.586896371721025
#     years         cos
# 50   2014  206.335545
# 51   2015  202.992777
# 52   2016  153.103284
# 53   2017  187.905184
# 54   2018  180.319563
# 55   2019  189.268399
# 56   2020  205.435536
# 57   2021  163.510463
# 58   2022  192.294210
# 59   2023  209.212802
# 60   2024  157.169541

# %%
CoS_df.index = CoS_df['years']
m, b, p_m, p_b = si.linear_fit(CoS_df, 'cos')
print(m, b, p_m, p_b)
print(f"Shift of center of storminess in days per year: {m}")
# Out:
# -0.15429053464529216 491.5873312683963 0.3640193570524628 0.14931830820562664
# Shift of center of storminess in days per year: -0.15429053464529216

# %% [markdown]
# # Plot

# %%
def trend_symbol(m, p, alpha=0.05):
    if p < alpha:
        return '↑' if m > 0 else '↓'
    else:
        return '–'

# %%
def adjust_intercept(asi_df, col, m, b_old):
    first_valid_year = asi_df[col].dropna().index[0]
    y_start = b_old 
    b_new = y_start - (m * first_valid_year)
    return b_new

# %%
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [TP_plot.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# colormap for years, corresponding to sum of the storm index of each year
cmap = cm.get_cmap('viridis') #'rainbow'
colors = cmap(ASI['all']/ASI['all'].max())
norm = plt.Normalize(0, ASI['all'].max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)

# limit trend lines to valid years + margin
x = ASI.index.to_numpy()
valid = ~np.isnan(ASI[['winter', 'all', 'summer']]).all(axis=1).to_numpy()
k = 2 # allow extrapolation up to ±2 years
valid_ext = np.convolve(valid.astype(int), np.ones(2*k+1, dtype=int), mode='same') > 0
x_tr = x[valid_ext]

# %% [markdown]
# ### Strong Storms Summer-Winter
# #### Mann Kendall

# %%
mk_results = {}

for col in strong_storms.columns:
    data_clean = strong_storms[col].dropna()
    #res = mk.original_test(data_clean)    # original Mann-Kendall test
    res = mk.hamed_rao_modification_test(data_clean)
    #res = mk.yue_wang_modification_test(data_clean)
    mk_results[col] = {
        'Trend': res.trend,
        'P-Value': res.p,
        'Tau': res.Tau,
        'Score': res.s,
        'Sen Slope': res.slope,
        'Intercept': res.intercept
    }
results_df = pd.DataFrame(mk_results).T
print(results_df)
# Out:
#                    Trend   P-Value       Tau  Score Sen Slope  Intercept
# count         increasing  0.000442  0.270621  479.0  0.377155  33.373922
# count summer    no trend  0.111782  0.139891  256.0   0.08422   7.473404
# count winter  increasing  0.002161  0.246328  436.0       0.3      22.15
# mean            no trend  0.055056  0.140113  248.0  0.007673   2.374321
# mean summer     no trend  0.498711  0.065941  109.0   0.00261   1.690036
# mean winter   increasing  0.037876   0.20565  364.0  0.011836   2.537458

# %%
#with open("MannKendall_COUNTS_MEAN.txt", "a") as f:
#with open("hr_MannKendall_COUNTS_MEAN.txt", "a") as f:
#with open("yw_MannKendall_COUNTS_MEAN.txt", "a") as f:
#    f.write(f"{station_name}\n")
#    f.write(results_df.to_string())
#    f.write("\n\n")

# %%
# --- COUNT SERIES ---
m0, b0_raw = results_df.loc['count', 'Sen Slope'], results_df.loc['count', 'Intercept']
b0 = adjust_intercept(strong_storms, 'count', m0, b0_raw)
p_m0 = results_df.loc['count', 'P-Value']

m1, b1_raw = results_df.loc['count winter', 'Sen Slope'], results_df.loc['count winter', 'Intercept']
b1 = adjust_intercept(strong_storms, 'count winter', m1, b1_raw)
p_m1 = results_df.loc['count winter', 'P-Value']

m2, b2_raw = results_df.loc['count summer', 'Sen Slope'], results_df.loc['count summer', 'Intercept']
b2 = adjust_intercept(strong_storms, 'count summer', m2, b2_raw)
p_m2 = results_df.loc['count summer', 'P-Value']


# --- MEAN SERIES ---
m3, b3_raw = results_df.loc['mean', 'Sen Slope'], results_df.loc['mean', 'Intercept']
b3 = adjust_intercept(strong_storms, 'mean', m3, b3_raw)
p_m3 = results_df.loc['mean', 'P-Value']

m4, b4_raw = results_df.loc['mean winter', 'Sen Slope'], results_df.loc['mean winter', 'Intercept']
b4 = adjust_intercept(strong_storms, 'mean winter', m4, b4_raw)
p_m4 = results_df.loc['mean winter', 'P-Value']

m5, b5_raw = results_df.loc['mean summer', 'Sen Slope'], results_df.loc['mean summer', 'Intercept']
b5 = adjust_intercept(strong_storms, 'mean summer', m5, b5_raw)
p_m5 = results_df.loc['mean summer', 'P-Value']

# %%
fig, ax = plt.subplots(1,2, figsize=(12,7), sharex=True, sharey=False, gridspec_kw={'width_ratios': [1, 1]})
plt.subplots_adjust(wspace=0.02)
if station_name == 'ScottBase':
    fig.suptitle('Scott Base', fontsize=30)
elif station_name == 'LaurieII':
    fig.suptitle('Laurie II', fontsize=30)
elif station_name == 'MarblePoint':
    fig.suptitle('Marble Point', fontsize=30)
else:
    fig.suptitle(station_name, fontsize=30)

ax[0].plot(x_tr, m0*x_tr+b0, color='black', linestyle=':', label=f'trend all months ({trend_symbol(m0, p_m0)})')
ax[0].plot(x_tr, m1*x_tr+b1, color='black', linestyle='-', label=f'trend only winter months ({trend_symbol(m1, p_m1)})')
ax[0].plot(x_tr, m2*x_tr+b2, color='black', linestyle='--', label=f'trend only summer months ({trend_symbol(m2, p_m2)})')
ax[0].plot(strong_storms.index, strong_storms['count winter'], color='deepskyblue', marker='*')
ax[0].plot(strong_storms.index, strong_storms['count'], color='slategray', marker='^')
ax[0].plot(strong_storms.index, strong_storms['count summer'], color='orange', marker='o')
ax[0].legend(fontsize=16, ncol=1)
ax[0].set_title('Count', fontsize=20)
ax[0].tick_params(labelsize=16)
ax[0].set_ylim((0,100))
ax[0].set_xlabel('Year', fontsize=20)
ax[0].set_ylabel('Count of Storm Days\nMore Stormy than Average', fontsize=20)

ax[1].plot(x_tr, m3*x_tr+b3, color='black', linestyle=':', label=f'trend all months ({trend_symbol(m3, p_m3)})')
ax[1].plot(x_tr, m4*x_tr+b4, color='black', linestyle='-', label=f'trend only winter months ({trend_symbol(m4, p_m4)})')
ax[1].plot(x_tr, m5*x_tr+b5, color='black', linestyle='--', label=f'trend only summer months ({trend_symbol(m5, p_m5)})')
ax[1].plot(strong_storms.index, strong_storms['mean winter'], color='deepskyblue', marker='*')
ax[1].plot(strong_storms.index, strong_storms['mean'], color='slategray', marker='^')
ax[1].plot(strong_storms.index, strong_storms['mean summer'], color='orange', marker='o')
ax[1].legend(fontsize=16, ncol=1)
ax[1].set_title('Strength', fontsize=20)
ax[1].tick_params(labelsize=16)
ax[1].set_ylim((0,5.5))
ax[1].set_xlabel('Year', fontsize=20)
ax[1].set_ylabel('Mean Strength of Storms More\nStormy than Average', fontsize=20)
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position("right")

plt.savefig('../Figures/'+str(station_name)+'_strong_storms_winter_summer', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Annual Storm Index
# #### Mann Kendall

# %%
mk_results = {}

for col in ASI.columns:
    data_clean = ASI[col].dropna()
    #res = mk.original_test(data_clean)    # original Mann-Kendall test
    res = mk.hamed_rao_modification_test(data_clean)
    #res = mk.yue_wang_modification_test(data_clean)
    mk_results[col] = {
        'Trend': res.trend,
        'P-Value': res.p,
        'Tau': res.Tau,
        'Score': res.s,
        'Sen Slope': res.slope,
        'Intercept': res.intercept
    }
results_df = pd.DataFrame(mk_results).T
print(results_df)
# Out:
#              Trend   P-Value       Tau  Score Sen Slope Intercept
# all     increasing  0.001896  0.275706  488.0  0.003649  0.274894
# winter  increasing  0.000115  0.264407  468.0  0.006488  0.388096
# summer    no trend  0.054495  0.169399  310.0  0.001591  0.161862

# %%
#with open("MannKendall_TRENDS.txt", "a") as f:
#with open("hr_MannKendall_TRENDS.txt", "a") as f:
#with open("yw_MannKendall_TRENDS.txt", "a") as f:
#    f.write(f"{station_name}\n")
#    f.write(results_df.to_string())
#    f.write("\n\n")

# %%
m1, b1_raw = results_df.loc['winter', 'Sen Slope'], results_df.loc['winter', 'Intercept']
m0, b0_raw = results_df.loc['all', 'Sen Slope'],    results_df.loc['all', 'Intercept']
m2, b2_raw = results_df.loc['summer', 'Sen Slope'], results_df.loc['summer', 'Intercept']

b1 = adjust_intercept(ASI, 'winter', m1, b1_raw)
b0 = adjust_intercept(ASI, 'all', m0, b0_raw)
b2 = adjust_intercept(ASI, 'summer', m2, b2_raw)

p_m1 = results_df.loc['winter', 'P-Value']
p_m0 = results_df.loc['all', 'P-Value']
p_m2 = results_df.loc['summer', 'P-Value']

# %%
fig, ax = plt.subplots(1,1, figsize=(10,8))

ax.plot(x_tr, m1*x_tr+b1, color='black', linestyle='-', label=f'trend only winter months ({trend_symbol(m1, p_m1)})')
ax.plot(x_tr, m0*x_tr+b0, color='black', linestyle=':', label=f'trend all months ({trend_symbol(m0, p_m0)})')
ax.plot(x_tr, m2*x_tr+b2, color='black', linestyle='--', label=f'trend only summer months ({trend_symbol(m2, p_m2)})')
ax.plot(ASI.index, ASI['winter'], color='deepskyblue', marker='*', label='only winter months')
ax.plot(ASI.index, ASI['all'], color='slategray', marker='^', label='all months')
ax.plot(ASI.index, ASI['summer'], color='orange', marker='o', label='only summer months')
ax.legend(fontsize=16, ncol=2)
if station_name == 'ScottBase':
    ax.set_title('Scott Base', fontsize=24)
elif station_name == 'LaurieII':
    ax.set_title('Laurie II', fontsize=24)
elif station_name == 'MarblePoint':
    ax.set_title('Marble Point', fontsize=24)
else:
    ax.set_title(station_name, fontsize=24)
ax.tick_params(labelsize=16)
ax.set_xlim((1963,2025))
ax.set_ylim((0,2))
ax.set_xlabel('Year', fontsize=20)
ax.set_ylabel('Mean Annual Storm Index', fontsize=20)

plt.savefig('../Figures/'+str(station_name)+'_asi_summer_line', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Inter-annual variability

# %%
window=3
ASI_std = ASI.rolling(window=window, center=True).std()
print(ASI_std.winter.loc[:2015].mean())
print(ASI_std.winter.loc[2016:].mean())
print(ASI_std.winter.loc[2016:].mean() / ASI_std.winter.loc[:2015].mean())
print(ASI_std.winter.loc[2017].mean() / ASI_std.winter.loc[1989].mean())

# Plot
fig, ax = plt.subplots(figsize=(10, 3.6))

ax.plot(ASI_std.index, ASI_std['winter'], marker='*', linestyle='-', label='Winter', color='deepskyblue')
ax.plot(ASI_std.index, ASI_std['all'], marker='^', linestyle='-', label='All', color='slategray')
ax.plot(ASI_std.index, ASI_std['summer'], marker='o', linestyle='-', label='Summer', color='orange')

ax.set_ylabel(str(window)+'-year Rolling Std Dev', fontsize=16)
ax.set_xlabel('Year', fontsize=16)
ax.legend(fontsize=14, ncol=1)
#ax.set_title(station_name, fontsize=20)
ax.tick_params(labelsize=16)
ax.grid(True)

plt.savefig('../Figures/'+str(station_name)+'_'+str(window)+'year_std', bbox_inches='tight')
plt.show()
# Out:
# 0.2131883858356864
# 0.5335693149925684
# 2.5028066744865436
# 1.2991662402497781
