# %% [markdown]
# # Storm Indices

# %%
import storm_indices as si

import numpy as np
import pandas as pd
import tqdm
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.patches as patches
import seaborn as sns
import glob as gl
from datetime import datetime, date, time, timedelta
import calendar
from scipy.optimize import curve_fit
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Choose Station

# %%
station_name = 'ScottBase'

#station_name = 'MarblePoint'
#station_name = 'CapeBird'
#station_name = 'Margaret'
#station_name = 'Vito'
#station_name = 'Ferrell'
#station_name = 'Manuela'
#station_name = 'Alessandra'
#station_name = 'Silvia'

#station_name = 'Phoenix'
#station_name = 'Willie'
#station_name = 'Whitlock'
#station_name = 'PossessionIsland'
#station_name = 'Gill'

# %% [markdown]
# ### Read in Temperature and Pressure Data

# %%
if station_name == 'ScottBase':
    # SCOTT BASE
    t_column_name = 'Mean Temperature [Deg C]'
    p_column_name = 'Mean sea level pressure [Hpa]'
    TP = pd.read_csv('../Data/scottbase/scottbase.csv')
    TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
    TP.index = TP['DateTime']
    del TP['DateTime']
elif station_name in ['Vito', 'MarblePoint', 'Manuela', 'Phoenix', 'Willie', 'Ferrell', 'Whitlock', 'PossessionIsland', 'CapeBird', 'Margaret', 'Gill']:
    # AMRC AWS
    if station_name == 'Vito':
        TP = pd.read_csv('../Data/vito/vito.csv')
    elif station_name == 'MarblePoint':
        TP = pd.read_csv('../Data/marblePoint/marblePoint.csv')
    elif station_name == 'Manuela':
        TP = pd.read_csv('../Data/manuela/manuela.csv')
    elif station_name == 'Phoenix':
        TP = pd.read_csv('../Data/phoenix/phoenix.csv')
    elif station_name == 'Willie':
        TP = pd.read_csv('../Data/willie/willie.csv')
    elif station_name == 'Ferrell':
        TP = pd.read_csv('../Data/ferrell/ferrell.csv')
    elif station_name == 'Whitlock':
        TP = pd.read_csv('../Data/whitlock/whitlock.csv')
    elif station_name == 'PossessionIsland':
        TP = pd.read_csv('../Data/possessionisland/possessionisland.csv')
    elif station_name == 'CapeBird':
        TP = pd.read_csv('../Data/capebird/capebird.csv')
    elif station_name == 'Margaret':
        TP = pd.read_csv('../Data/margaret/margaret.csv')
    elif station_name == 'Gill':
        TP = pd.read_csv('../Data/gill/gill.csv')
    t_column_name = 'temperature'
    p_column_name = 'pressure'
    TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
    TP.index = TP['DateTime']
    del TP['DateTime']
else:
    # WANG et al, 2022
    if station_name == 'Alessandra':
        TP = pd.read_csv('../Data/alessandra/alessandra.csv')
    elif station_name == 'Silvia':
        TP = pd.read_csv('../Data/silvia/silvia.csv')
    t_column_name = 'temperature_C'
    p_column_name = 'pressure_hPa'
    TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
    TP.index = TP['DateTime']
    del TP['DateTime']

# %%
TP = TP[[t_column_name, p_column_name]]
TP = TP[~TP.index.isna()]

TP
# Out:
#             Mean Temperature [Deg C]  Mean sea level pressure [Hpa]
# DateTime
# 1964-09-30                       NaN                    1005.000000
# 1964-10-01                     -24.6                     997.600000
# 1964-10-02                     -25.8                     997.400000
# 1964-10-03                     -28.3                     989.100000
# 1964-10-04                     -26.2                     976.200000
# ...                              ...                            ...
# 2025-05-11                     -26.0                     998.166667
# 2025-05-12                     -28.8                    1003.366667
# 2025-05-13                     -31.3                    1001.595833
# 2025-05-14                     -31.9                     999.029167
# 2025-05-15                       NaN                     996.525000
#
# [22101 rows x 2 columns]

# %% [markdown]
# ### Get Start and End Year

# %%
#start_year = int(np.min(TP.index.year))
start_year = 1964
#end_year = int(np.max(TP.index.year))
end_year = 2024
print(start_year, end_year)
years = np.array([int(i) for i in range(start_year, end_year+1)], dtype=int)
full_index = pd.date_range(start=str(start_year)+"-01-01", end=str(end_year)+"-12-31", freq="D")
TP = TP.reindex(full_index)
# Out:
# 1964 2024

# %% [markdown]
# ### Compute Storm Index

# %%
TP = si.compute_si(TP, t_column_name, p_column_name, 'SI')
TP
# Out:
#             Mean Temperature [Deg C]  Mean sea level pressure [Hpa]   SI
# 1964-01-01                       NaN                            NaN  NaN
# 1964-01-02                       NaN                            NaN  NaN
# 1964-01-03                       NaN                            NaN  NaN
# 1964-01-04                       NaN                            NaN  NaN
# 1964-01-05                       NaN                            NaN  NaN
# ...                              ...                            ...  ...
# 2024-12-27                      -3.4                     988.891667  0.0
# 2024-12-28                      -4.7                     991.658333  0.0
# 2024-12-29                      -2.9                     991.687500  0.0
# 2024-12-30                      -1.2                     986.000000  0.0
# 2024-12-31                      -0.9                     988.658333  0.0
#
# [22281 rows x 3 columns]

# %% [markdown]
# ### How many storms are stormier than average?

# %%
# Fraction of strong storm days in all storm days
fraction_of_strong_storms = (TP['SI'] > 1).sum() / (TP['SI'] > 0).sum()
# Fraction of strong storm days in all days
fraction_of_strong_storms_of_all_days = (TP['SI'] > 1).sum() / TP['SI'].notna().sum()
# How many of the strong storm days happen in winter?
TP_copy = TP.copy()
#TP_copy = TP.loc['1995-01-01':'2024-12-31'] # optionally limit to certain time ('1965-01-01':'1994-12-31' or '1995-01-01':'2024-12-31')
si_above_1 = TP_copy['SI'] > 1
days_with_si = TP_copy[si_above_1]
winter_months = [4, 5, 6, 7, 8, 9]
winter_days_with_si = days_with_si.index.month.isin(winter_months).sum()
total_days_with_si = si_above_1.sum()
winter_fraction_of_strong_storm_days = winter_days_with_si / total_days_with_si if total_days_with_si > 0 else float('nan')

print(fraction_of_strong_storms)
print(fraction_of_strong_storms_of_all_days)
print(winter_fraction_of_strong_storm_days)
# Out:
# 0.28119891008174386
# 0.11764705882352941
# 0.7612403100775194

# %% [markdown]
# ### How many storms that are stormier than average are there per year? And what is their average storminess?

# %%
TP_summer = TP[TP.index.month.isin([1, 2, 3, 10, 11, 12])]
TP_winter = TP[TP.index.month.isin([4, 5, 6, 7, 8, 9])]
count = (TP['SI'] > 1).groupby(TP.index.year).sum().to_frame(name='count')
count_summer = (TP_summer['SI'] > 1).groupby(TP_summer.index.year).sum().to_frame(name='count summer')
count_winter = (TP_winter['SI'] > 1).groupby(TP_winter.index.year).sum().to_frame(name='count winter')
mean = TP[TP['SI'] > 1].groupby(TP[TP['SI'] > 1].index.year)['SI'].mean().to_frame(name='mean')
mean_summer = TP_summer[TP_summer['SI'] > 1].groupby(TP_summer[TP_summer['SI'] > 1].index.year)['SI'].mean().to_frame(name='mean summer')
mean_winter = TP_winter[TP_winter['SI'] > 1].groupby(TP_winter[TP_winter['SI'] > 1].index.year)['SI'].mean().to_frame(name='mean winter')
strong_storms = pd.concat([count, count_summer, count_winter, mean, mean_summer, mean_winter], axis=1)
strong_storms
# Out:
#       count  count summer  count winter      mean  mean summer  mean winter
# 1964      4             4             0  1.075264     1.075264          NaN
# 1965     29            15            14  2.019990     2.544846     1.457645
# 1966     45            15            30  2.406823     1.840163     2.690153
# 1967     48             4            44  3.307163     1.218549     3.497037
# 1968     28             4            24  3.082230     1.546346     3.338211
# ...     ...           ...           ...       ...          ...          ...
# 2020     56            16            40  3.242557     1.943122     3.762331
# 2021     28             1            27  3.086947     1.093876     3.160764
# 2022     84            26            58  3.258591     1.972030     3.835325
# 2023     35            16            19  2.546989     1.481737     3.444043
# 2024     65            17            48  2.727477     1.989595     2.988810
#
# [61 rows x 6 columns]

# %% [markdown]
# ### Compute Climatologies

# %%
SI_clim,_ = si.compute_climatologies(TP, 'SI', p_column_name)
si_clim_df = SI_clim.reset_index(name='SI_clim')

# %%
T_clim, P_clim = si.compute_climatologies(TP, t_column_name, p_column_name)
t_clim_df = T_clim.reset_index(name='T_clim')
p_clim_df = P_clim.reset_index(name='P_clim')
clim_df = pd.merge(t_clim_df, p_clim_df, on=['month', 'day'], how='left')
clim_df = pd.merge(si_clim_df, clim_df, on=['month', 'day'], how='left')
clim_df['month_day'] = clim_df['month'].astype(str) + '-' + clim_df['day'].astype(str)
clim_df.index = clim_df['month_day']
clim_df.drop(columns=['month', 'day', 'month_day'], inplace=True)
clim_df.index = clim_df.index.to_series().apply(
    lambda x: '-'.join(f'{int(part):02d}' for part in x.split('-'))
)
clim_df
# Out:
#             SI_clim    T_clim      P_clim
# month_day
# 01-01      0.108042 -2.968611  992.122338
# 01-02      0.095079 -3.038889  991.826644
# 01-03      0.082866 -3.121111  991.654606
# 01-04      0.069577 -3.299444  992.055116
# 01-05      0.062830 -3.447222  992.454518
# ...             ...       ...         ...
# 12-27      0.194370 -3.467760  991.104349
# 12-28      0.188611 -3.146448  991.316598
# 12-29      0.161430 -2.903279  991.255829
# 12-30      0.136744 -2.758743  991.463138
# 12-31      0.115124 -2.870492  991.966940
#
# [366 rows x 3 columns]

# %% [markdown]
# ### Compute Annual and Seasonal Sums of Storm Index

# %%
min_days = 183
min_days_winter = 92

TP['year'] = TP.index.year
TP_winter = TP.copy()
TP_winter['month'] = TP_winter.index.month
TP_winter['winter'] = np.where(TP_winter['month'].isin([4, 5, 6, 7, 8, 9]), True, False)
TP_winter = TP_winter[TP_winter['winter'] == True]
TP_summer = TP.copy()
TP_summer['month'] = TP_summer.index.month
TP_summer['summer'] = np.where(TP_summer['month'].isin([1, 2, 3, 10, 11, 12]), True, False)
TP_summer = TP_summer[TP_summer['summer'] == True]

# sum up and divide by the count of non-nan-values per year/winter for an annual/seasonal storm index with a per-day unit
number_of_non_nan_days = TP.groupby(['year'])['SI'].count()
annual = TP.groupby(['year'])['SI'].sum() / number_of_non_nan_days
number_of_non_nan_days_winter = TP_winter.groupby(['year'])['SI'].count()
seasonal = TP_winter.groupby(['year'])['SI'].sum() / number_of_non_nan_days_winter
number_of_non_nan_days_summer = TP_summer.groupby(['year'])['SI'].count()
seasonal_summer = TP_summer.groupby(['year'])['SI'].sum() / number_of_non_nan_days_summer

del TP['year']

# handle data gaps
full_years = pd.Index(range(start_year, end_year + 1), name='year')
annual = annual.reindex(full_years)
seasonal = seasonal.reindex(full_years)
seasonal_summer = seasonal_summer.reindex(full_years)
invalid_years = number_of_non_nan_days[number_of_non_nan_days < min_days].index
invalid_years_winter = number_of_non_nan_days_winter[number_of_non_nan_days_winter < min_days_winter].index
invalid_years_summer = number_of_non_nan_days_summer[number_of_non_nan_days_summer < min_days_winter].index
annual.loc[invalid_years] = np.nan
seasonal.loc[invalid_years_winter] = np.nan
seasonal_summer.loc[invalid_years_summer] = np.nan

# %%
ASI = pd.DataFrame({'all':annual.values, 'winter':seasonal.values, 'summer':seasonal_summer.values}, index=full_years)
ASI
# Out:
#            all    winter    summer
# year
# 1964       NaN       NaN  0.103995
# 1965  0.235393  0.193113  0.277906
# 1966  0.395352  0.570359  0.218410
# 1967  0.506863  0.911190  0.100315
# 1968  0.289025  0.494160  0.083890
# ...        ...       ...       ...
# 2020  0.619466  0.952674  0.286258
# 2021  0.329004  0.559573  0.097168
# 2022  0.836189  1.298998  0.370837
# 2023  0.355515  0.427357  0.283279
# 2024  0.584374  0.858192  0.310557
#
# [61 rows x 3 columns]

# %% [markdown]
# ### Prepare Second Dataframe with years split into columns (helpful for plotting)

# %%
df = TP.copy()

df['month_day'] = df.index.strftime('%m-%d')
df['year'] = df.index.year

# Create a new DataFrame with desired structure
TP_plot = pd.concat([
    df.pivot(index='month_day', columns='year', values=t_column_name).add_prefix('T'),
    df.pivot(index='month_day', columns='year', values=p_column_name).add_prefix('P'),
    df.pivot(index='month_day', columns='year', values='SI').add_prefix('SI')
], axis=1)

TP_plot
# Out:
# year       T1964  T1965  T1966  T1967  T1968  T1969  T1970  T1971  T1972  \
# month_day
# 01-01        NaN   -4.5   -1.8   -2.0   -1.3   -1.7   -1.1    0.4   -2.0
# 01-02        NaN   -4.4   -2.4   -2.3   -3.2   -6.2   -2.1    1.3   -2.7
# 01-03        NaN   -2.0   -3.7   -3.6   -4.6   -6.4   -4.2    1.5   -1.4
# 01-04        NaN   -7.3   -4.2    0.2   -2.7   -6.1   -4.0    1.4   -1.6
# 01-05        NaN   -3.8   -3.9    1.3   -2.7   -7.7   -2.0   -0.5   -6.5
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 12-27       -3.9   -2.4   -2.8   -3.0   -2.0   -2.9   -6.0   -3.7   -3.3
# 12-28       -0.5   -3.6   -5.0   -8.1   -0.5   -1.3   -8.3   -6.5   -4.9
# 12-29       -0.3   -0.7   -5.4   -3.6   -2.0   -0.4   -4.8   -4.5   -6.0
# 12-30       -0.3   -0.5   -1.4   -3.6   -1.4   -0.2   -3.0   -1.0   -4.4
# 12-31       -2.0   -2.3   -2.8   -3.1   -1.1    0.0   -2.0   -2.2   -3.8
#
# year       T1973  ...    SI2015    SI2016    SI2017    SI2018    SI2019  \
# ...

# %% [markdown]
# ### Compute Center of Storminess and Width of Storminess Distribution per Year

# %%
invalid_years = {}

# %%
CoS = []                              # DoY of Center of Storminess per year.
a = np.arange(len(TP_plot))
for i in years:
    weights = TP_plot['SI'+str(i)]
    masked_weights = np.ma.MaskedArray(weights, mask=np.isnan(weights))
    if masked_weights.count() < 335:
        CoS.append(np.nan)
        invalid_years[i] = True
    else:
        center = np.ma.average(a, weights=masked_weights)
        CoS.append(center)
        invalid_years[i] = False
CoS_df = pd.DataFrame({'years': years, 'cos': CoS})
CoS_df[50:]
# Out:
#     years         cos
# 50   2014  205.662086
# 51   2015  205.250811
# 52   2016  148.930142
# 53   2017  187.580170
# 54   2018  170.476233
# 55   2019  188.074573
# 56   2020  198.908390
# 57   2021  164.583838
# 58   2022  196.827871
# 59   2023  206.054504
# 60   2024  154.726646

# %%
# Gaussian function
def gaussian(x, A, mu, sigma):
    return A * np.exp(-(x - mu)**2 / (2 * sigma**2))


bell_parameters = {}

events_all_years = TP.copy()
events_all_years = events_all_years[events_all_years['SI'] > 0]
for year in years:
    try:
        events = events_all_years.loc[str(year)]
        
        doy = events.index.dayofyear
        values = events['SI'].values
        
        params, _ = curve_fit(gaussian, doy, values, p0=[1, 180, 30])
        bell_parameters[year] = params
    except:
        continue
    
bell_parameters = pd.DataFrame({
    'years': list(bell_parameters.keys()),
    'amplitude': [p[0] for p in bell_parameters.values()],
    'mu':        [p[1] for p in bell_parameters.values()],
    'sigma':     [p[2] for p in bell_parameters.values()]
})
invalid_mask = bell_parameters['years'].map(invalid_years)
bell_parameters.loc[invalid_mask, ['amplitude', 'mu', 'sigma']] = np.nan

bell_parameters
# Out:
#     years  amplitude          mu       sigma
# 0    1964        NaN         NaN         NaN
# 1    1965   0.820400  177.255098  148.562470
# 2    1966   1.511722  201.216338   83.534658
# 3    1967   3.123463  188.680343   46.325586
# 4    1968   1.901219  152.785814   88.749576
# ..    ...        ...         ...         ...
# 56   2020   2.083998  200.100324   81.447119
# 57   2021   1.528148  169.010215   79.332206
# 58   2022   2.602989  192.217743   81.524476
# 59   2023   1.738978  226.349210   76.600897
# 60   2024   2.514142  139.238917   41.916314
#
# [61 rows x 4 columns]

# %% [markdown]
# ### Compute Inter-Annual Trends Extremes

# %%
df_anomalies = si.compute_anomalies(TP, t_column_name, p_column_name)
df_anomalies
# Out:
#             T_anom  P_anom
# 1964-01-01     NaN     NaN
# 1964-01-02     NaN     NaN
# 1964-01-03     NaN     NaN
# 1964-01-04     NaN     NaN
# 1964-01-05     NaN     NaN
# ...            ...     ...
# 2024-12-27     NaN     NaN
# 2024-12-28     NaN     NaN
# 2024-12-29     NaN     NaN
# 2024-12-30     NaN     NaN
# 2024-12-31     NaN     NaN
#
# [22281 rows x 2 columns]

# %% [markdown]
# ### Compute Monthly Sums of Storm Index Normalized by Number of Valid Days

# %%
MSI = TP_plot.copy()
MSI = MSI[['SI'+str(i) for i in range(start_year, end_year+1)]]
MSI['month'] = MSI.index.str.split('-').str[0]
MSI['month'] = MSI['month'].astype('int')
valid_counts = MSI.groupby('month').count()
MSI = MSI.groupby('month').sum(min_count=20) / valid_counts
MSI.columns = MSI.columns.str.extract('(\d+)')[0].astype(int)
MSI.to_csv('../Data/'+str(station_name)+'/'+str(station_name)+'_monthly.csv')
MSI
# Out:
# 0          1964      1965      1966      1967      1968      1969      1970  \
# month
# 1           NaN  0.073352  0.393529  0.019986  0.111544  0.001743  0.042736
# 2           NaN  0.000000  0.000000  0.000000  0.056355  0.006614  0.115912
# 3           NaN  0.833537  0.000000  0.200096  0.000000  0.000196  0.039798
# 4           NaN  0.111246  0.188516  0.066122  1.157265  0.000000  0.211424
# 5           NaN  0.040462  0.003586  0.388408  0.149643  0.337014  0.716952
# 6           NaN  0.137212  1.510658  2.064836  0.260414  0.020005  0.741907
# 7           NaN  0.331871  0.602510  0.753137  1.292149  0.156690  0.010412
# 8           NaN  0.470200  0.663915  1.795678  0.103396  0.396134  0.237414
# 9           NaN  0.058913  0.467673  0.392171  0.000000  0.370490  0.124469
# 10     0.188686  0.448167  0.708506  0.258318  0.217199  0.106011  0.051784
# 11     0.016093  0.241352  0.149907  0.031963  0.008010  0.094536  0.134532
# ...

# %% [markdown]
# # Plot

# %%
# format x-axis
month_starts = [f'{m}-01' for m in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']]
month_start_positions = [TP_plot.index.get_loc(month_start) for month_start in month_starts]
month_start_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# colormap for years, corresponding to sum of the storm index of each year
cmap = cm.get_cmap('viridis') #'rainbow'
colors = cmap(ASI['all']/ASI['all'].max())
norm = plt.Normalize(0, ASI['all'].max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)

# %% [markdown]
# ### Illustrate Storm Index

# %%
fig, ax = plt.subplots(4,1, figsize=(15,8), sharex=True, sharey=False, gridspec_kw={'height_ratios': [4,3,3,4]})
plt.subplots_adjust(hspace=0.)

T_mean = TP_plot[[f'T{year}' for year in years]].mean(axis=1)
T_std = TP_plot[[f'T{year}' for year in years]].std(axis=1)
P_mean = TP_plot[[f'P{year}' for year in years]].mean(axis=1)
P_std = TP_plot[[f'P{year}' for year in years]].std(axis=1)
ax[1].fill_between(TP_plot.index, T_mean - T_std, T_mean + T_std, color='gray', alpha=0.9, zorder=2)
ax[2].fill_between(TP_plot.index, P_mean - P_std, P_mean + P_std, color='gray', alpha=0.9, zorder=2)
ax[1].plot(clim_df.index, clim_df['T_clim'], color='black', linestyle=':')
ax[2].plot(clim_df.index, clim_df['P_clim'], color='black', linestyle=':')

ax[0].plot(TP_plot.index, TP_plot['SI2019'], color='red', label='2019')
ax[1].plot(TP_plot.index, TP_plot['T2019'], color='black', zorder=1, label='2019')
ax[2].plot(TP_plot.index, TP_plot['P2019'], color='black', zorder=1, label='2019')
ax[3].plot(TP_plot.index, TP_plot['SI2020'], label='2020')
ax[3].plot(TP_plot.index, TP_plot['SI2021'], label='2021')
ax[3].plot(TP_plot.index, TP_plot['SI2022'], label='2022')
ax[3].plot(TP_plot.index, TP_plot['SI2023'], label='2023')
ax[3].plot(TP_plot.index, TP_plot['SI2024'], label='2024')

for j in [0,1,2,3]:
    ax[j].axvspan('01-01', '04-01', facecolor='0.9', zorder=0)
    ax[j].axvspan('09-30', '12-31', facecolor='0.9', zorder=0)

# formatting
ax[0].set_title(str(station_name)+' - 2019', fontsize=28)
for j in [0,1,2,3]:
    ax[j].tick_params(labelsize=14)
ax[0].set_xticks(ticks=month_start_positions, labels=month_start_labels, rotation=45)
ax[0].set_xlim(('01-01', '12-31'))
ax[0].set_ylim((0, 16))
ax[1].set_ylim((-48, 8))
ax[3].set_ylim((0, 16))
ax[0].set_ylabel('Storm Index', fontsize=14)
ax[1].set_ylabel('T in °C', fontsize=14)
ax[2].set_ylabel('MSLP\nin hPa', fontsize=14)
ax[3].set_ylabel('Storm Index', fontsize=14)
for j in [0,1,2,3]:
    ax[j].yaxis.set_ticks_position('both')
    ax[j].tick_params(labelright=True)
    ax[j].spines['right'].set_visible(True)
ax[0].legend(fontsize=14, loc=1)
ax[1].legend(fontsize=14, loc=4)
ax[2].legend(fontsize=14, loc=4)
ax[3].legend(fontsize=14, loc=1)
ax[0].yaxis.label.set_color('red')
ax[0].tick_params(axis='y', colors='red')

plt.show()

# %% [markdown]
# ### Total Time Series

# %%
print('ALL')
m0, b0, p_m0, p_b0 = si.linear_fit(TP, 'SI')
print(m0, b0, p_m0, p_b0)
m1, b1, p_m1, p_b1 = si.linear_fit(TP, t_column_name)
print(m1, b1, p_m1, p_b1)
m2, b2, p_m2, p_b2 = si.linear_fit(TP, p_column_name)
print(m2, b2, p_m2, p_b2)
print('WINTER')
m0w, b0w, p_m0w, p_b0w = si.linear_fit(TP_winter, 'SI')
print(m0w, b0w, p_m0w, p_b0w)
m1w, b1w, p_m1w, p_b1w = si.linear_fit(TP_winter, t_column_name)
print(m1w, b1w, p_m1w, p_b1w)
m2w, b2w, p_m2w, p_b2w = si.linear_fit(TP_winter, p_column_name)
print(m2w, b2w, p_m2w, p_b2w)
# Out:
# ALL
# 1.4294588887751033e-05 0.25735625648526567 0.0 0.0
# 4.4083188472598955e-05 -20.023006480295017 9.399701538170824e-05 0.0
# -0.00023414569487623105 992.4879621063262 0.0 0.0
# WINTER
# 2.524063842222302e-05 0.34910380445222966 0.0 0.0
# 7.897614840466731e-05 -27.82827643803588 3.0242475190789264e-13 0.0
# -0.0001992573547908716 992.4815410479787 0.0 0.0

# %%
fig, ax = plt.subplots(3, 1, figsize=(20, 8), sharex=True, sharey=False, gridspec_kw={'height_ratios': [3, 2, 2]})
plt.subplots_adjust(hspace=0.)

grouped = TP.groupby(TP.index.year)
for year, group in grouped:
    ax[0].plot(group.index, group['SI'], color=colors[int(year)-start_year])
    ax[1].plot(group.index, group[t_column_name], color=colors[int(year)-start_year])
    ax[2].plot(group.index, group[p_column_name], color=colors[int(year)-start_year])

ax[0].plot(TP.index, m0 * np.arange(len(TP.index)) + b0, color='black', label=f'slope = {round(float(10*365.25*m0), 5)}/decade\n(winter only: {round(float(10*365.25*m0w), 5)})')
ax[1].plot(TP.index, m1 * np.arange(len(TP.index)) + b1, color='black', label=f'slope = {round(float(10*365.25*m1), 3)}°C/decade\n(winter only: {round(float(10*365.25*m1w), 3)})')
ax[2].plot(TP.index, m2 * np.arange(len(TP.index)) + b2, color='black', label=f'slope = {round(float(10*365.25*m2), 3)}hPa/decade\n(winter only: {round(float(10*365.25*m2w), 3)})')

# formatting
for j in [0, 1, 2]:
    ax[j].tick_params(labelsize=14)
    ax[j].grid()
    ax[j].legend(fontsize=14, loc=2)
    ax[j].set_xlim((datetime(start_year, 1, 1), datetime(2024, 9, 11)))
ax[0].set_ylabel('SI', fontsize=16)
ax[1].set_ylabel('Temperature\nin °C', fontsize=14)
ax[2].set_ylabel('Mean Sea\nLevel Pressure\nin hPa', fontsize=14)
ax[2].set_xlabel('Date', fontsize=16)
ax[0].set_title(station_name, fontsize=20)

# colorbar
cbar = plt.colorbar(sm, ax=ax[:], orientation='vertical', fraction=0.01, aspect=45, pad=0.02)
cbar.set_label('Annual Storm Index (per day)', fontsize=14)

plt.savefig('../Figures/'+str(station_name)+'_total_time_series', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Anomalies

# %%
m0, b0, p_m0, p_b0 = si.linear_fit(df_anomalies, 'T_anom')
m1, b1, p_m1, p_b1 = si.linear_fit(df_anomalies, 'P_anom')

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 8), sharex=True, sharey=False, gridspec_kw={'height_ratios': [1, 1]})
plt.subplots_adjust(hspace=0.)

grouped = df_anomalies.groupby(df_anomalies.index.year)
for year, group in grouped:
    ax[0].plot(group.index, group['T_anom'], color=colors[int(year)-start_year])
    ax[1].plot(group.index, group['P_anom'], color=colors[int(year)-start_year])

ax[0].plot(df_anomalies.index, m0 * np.arange(len(df_anomalies.index)) + b0, color='black', label=f'slope = {round(float(10*365.25*m0), 3)}°C/decade')
ax[1].plot(df_anomalies.index, m1 * np.arange(len(df_anomalies.index)) + b1, color='black', label=f'slope = {round(float(10*365.25*m1), 3)}hPa/decade')

# formatting
for j in [0, 1]:
    ax[j].tick_params(labelsize=14)
    ax[j].grid()
    ax[j].legend(fontsize=14, loc=2)
    ax[j].set_xlim((datetime(start_year, 1, 1), datetime(2024, 9, 11)))
ax[0].set_ylabel('Temperature\nanomalies in °C', fontsize=14)
ax[1].set_ylabel('Mean Sea Level Pressure\nanomalies in hPa', fontsize=14)
ax[1].set_xlabel('Date', fontsize=16)
ax[0].set_title(station_name, fontsize=20)

# colorbar
cbar = plt.colorbar(sm, ax=ax[:], orientation='vertical', fraction=0.01, aspect=45, pad=0.02)
cbar.set_label('Annual Storm Index (per day)', fontsize=14)

plt.savefig('../Figures/'+str(station_name)+'_total_time_series_anomalies', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Count and strength of strong storms per year

# %%
m0, b0, p_m0, p_b0 = si.linear_fit(strong_storms, 'count')
m1, b1, p_m1, p_b1 = si.linear_fit(strong_storms, 'mean')

# %%
fig, ax = plt.subplots(1,2, figsize=(12,7), sharex=True, sharey=False, gridspec_kw={'width_ratios': [1, 1]})
plt.subplots_adjust(wspace=0.02)
fig.suptitle(station_name, fontsize=30)

ax[0].plot(strong_storms.index, m0*strong_storms.index+b0, color='black', linestyle='-', label=f'trend_all ({round(float(10*m0), 4)}/dedace)')
ax[0].bar(strong_storms.index, strong_storms['count'], color='lightgrey', edgecolor='black')
ax[0].legend(fontsize=16, ncol=2)
ax[0].set_title('count', fontsize=20)
ax[0].tick_params(labelsize=14)
ax[0].set_ylim((0,100))
ax[0].set_xlabel('year', fontsize=18)
ax[0].set_ylabel('count of storm days\nmore stormy than average', fontsize=18)

ax[1].plot(strong_storms.index, m1*strong_storms.index+b1, color='black', linestyle='-', label=f'trend_all ({round(float(10*m1), 4)}/dedace)')
ax[1].bar(strong_storms.index, strong_storms['mean'], color='slategrey', edgecolor='black')
ax[1].legend(fontsize=16, ncol=2)
ax[1].set_title('strength', fontsize=20)
ax[1].tick_params(labelsize=14)
ax[1].set_ylim((0,5.5))
ax[1].set_xlabel('year', fontsize=18)
ax[1].set_ylabel('mean strength of storms more\nstormy than average', fontsize=18)
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position("right")

plt.savefig('../Figures/'+str(station_name)+'_strong_storms', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(2,1, figsize=(7,12), sharex=True, sharey=False, gridspec_kw={'height_ratios': [1, 1]})
plt.subplots_adjust(wspace=0.02)
fig.suptitle(station_name, fontsize=30)

ax[0].plot(strong_storms.index, m0*strong_storms.index+b0, color='black', linestyle='-', label=f'trend_all ({round(float(10*m0), 4)}/dedace)')
ax[0].bar(strong_storms.index, strong_storms['count'], color='lightgrey', edgecolor='black')
ax[0].legend(fontsize=16, ncol=2)
ax[0].set_title('count', fontsize=20)
ax[0].tick_params(labelsize=14)
ax[0].set_ylim((0,100))
ax[0].set_xlabel('year', fontsize=18)
ax[0].set_ylabel('count of storm days\nmore stormy than average', fontsize=18)

ax[1].plot(strong_storms.index, m1*strong_storms.index+b1, color='black', linestyle='-', label=f'trend_all ({round(float(10*m1), 4)}/dedace)')
ax[1].bar(strong_storms.index, strong_storms['mean'], color='slategrey', edgecolor='black')
ax[1].legend(fontsize=16, ncol=2)
ax[1].set_title('strength', fontsize=20)
ax[1].tick_params(labelsize=14)
ax[1].set_ylim((0,5.5))
ax[1].set_xlabel('year', fontsize=18)
ax[1].set_ylabel('mean strength of storms more\nstormy than average', fontsize=18)

plt.show()

# %% [markdown]
# ### Strong Storms Summer-Winter

# %%
m0, b0, p_m0, p_b0 = si.linear_fit(strong_storms, 'count')
m1, b1, p_m1, p_b1 = si.linear_fit(strong_storms, 'count winter')
m2, b2, p_m2, p_b2 = si.linear_fit(strong_storms, 'count summer')
m3, b3, p_m3, p_b3 = si.linear_fit(strong_storms, 'mean')
m4, b4, p_m4, p_b4 = si.linear_fit(strong_storms, 'mean winter')
m5, b5, p_m5, p_b5 = si.linear_fit(strong_storms, 'mean summer')

# %%
fig, ax = plt.subplots(1,2, figsize=(12,7), sharex=True, sharey=False, gridspec_kw={'width_ratios': [1, 1]})
plt.subplots_adjust(wspace=0.02)
fig.suptitle(station_name, fontsize=30)

ax[0].plot(strong_storms.index, m0*strong_storms.index+b0, color='black', linestyle='-', label=f'trend_all ({round(float(10*m0), 4)}/decade)')
ax[0].plot(strong_storms.index, m1*strong_storms.index+b1, color='black', linestyle=':', label=f'trend_winter ({round(float(10*m1), 4)}/decade)')
ax[0].plot(strong_storms.index, m2*strong_storms.index+b2, color='black', linestyle='--', label=f'trend_summer ({round(float(10*m2), 4)}/decade)')
ax[0].bar(strong_storms.index, strong_storms['count'], color='slategrey', edgecolor='white', linewidth=0.2)
ax[0].bar(strong_storms.index, strong_storms['count winter'], color='deepskyblue', edgecolor='white', linewidth=0.2)
ax[0].bar(strong_storms.index, strong_storms['count summer'], color='orange', edgecolor='white', linewidth=0.2)
ax[0].bar(strong_storms.index, np.where((strong_storms['count winter'] < strong_storms['count summer']), strong_storms['count winter'], 0), color='deepskyblue', edgecolor='white', linewidth=0.2)
ax[0].legend(fontsize=16, ncol=1)
ax[0].set_title('count', fontsize=20)
ax[0].tick_params(labelsize=14)
ax[0].set_ylim((0,100))
ax[0].set_xlabel('year', fontsize=18)
ax[0].set_ylabel('count of storm days\nmore stormy than average', fontsize=18)

ax[1].plot(strong_storms.index, m3*strong_storms.index+b3, color='black', linestyle='-', label=f'trend_all ({round(float(10*m3), 4)}/decade)')
ax[1].plot(strong_storms.index, m4*strong_storms.index+b4, color='black', linestyle=':', label=f'trend_winter ({round(float(10*m4), 4)}/decade)')
ax[1].plot(strong_storms.index, m5*strong_storms.index+b5, color='black', linestyle='--', label=f'trend_summer ({round(float(10*m5), 4)}/decade)')
ax[1].bar(strong_storms.index, strong_storms['mean winter'], color='deepskyblue', edgecolor='white', linewidth=0.2)
ax[1].bar(strong_storms.index, strong_storms['mean'], color='slategrey', edgecolor='white', linewidth=0.2)
ax[1].bar(strong_storms.index, strong_storms['mean summer'], color='orange', edgecolor='white', linewidth=0.2)
ax[1].bar(strong_storms.index, np.where((strong_storms['mean'] < strong_storms['mean summer']), strong_storms['mean'], 0), color='slategrey', edgecolor='white', linewidth=0.2)
ax[1].bar(strong_storms.index, np.where((strong_storms['mean winter'] < strong_storms['mean']), strong_storms['mean winter'], 0), color='deepskyblue', edgecolor='white', linewidth=0.2)
ax[1].legend(fontsize=16, ncol=1)
ax[1].set_title('strength', fontsize=20)
ax[1].tick_params(labelsize=14)
ax[1].set_ylim((0,5.5))
ax[1].set_xlabel('year', fontsize=18)
ax[1].set_ylabel('mean strength of storms more\nstormy than average', fontsize=18)
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position("right")

plt.savefig('../Figures/'+str(station_name)+'_strong_storms_winter_summer', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Annual Storm Index

# %%
m0, b0, p_m0, p_b0 = si.linear_fit(ASI, 'all')
m1, b1, p_m1, p_b1 = si.linear_fit(ASI, 'winter')
m2, b2, p_m2, p_b2 = si.linear_fit(ASI, 'summer')

# %%
fig, ax = plt.subplots(1,1, figsize=(10,8))

ax.plot(ASI.index, m1*ASI.index+b1, color='black', linestyle=':', label=f'trend_winter ({round(float(10*m1), 4)}/decade)')
ax.plot(ASI.index, m0*ASI.index+b0, color='black', linestyle='-', label=f'trend_all ({round(float(10*m0), 4)}/decade)')
ax.plot(ASI.index, m2*ASI.index+b2, color='black', linestyle='--', label=f'trend_summer ({round(float(10*m2), 4)}/decade)')
ax.bar(ASI.index, ASI['winter'], color='deepskyblue', edgecolor='white', label='only winter months')
ax.bar(ASI.index, ASI['all'], color='slategray', edgecolor='white', label='all months')
ax.bar(ASI.index, ASI['summer'], color='orange', edgecolor='white', label='only summer months')
ax.bar(ASI.index, np.where((ASI['all'] < ASI['summer']), ASI['all'], 0), color='slategray', edgecolor='white')
ax.bar(ASI.index, np.where((ASI['winter'] < ASI['all']), ASI['winter'], 0), color='deepskyblue', edgecolor='white')
ax.legend(fontsize=16, ncol=2)
ax.set_title(station_name, fontsize=20)
ax.tick_params(labelsize=14)
ax.set_ylim((0,2))
ax.set_xlabel('year', fontsize=18)
ax.set_ylabel('annual storm index (per day)', fontsize=18)

plt.savefig('../Figures/'+str(station_name)+'_asi_summer', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(10,8))
ax.plot(ASI.index, m0*ASI.index+b0, color='black', linestyle='-', label=f'trend_all ({round(float(10*m0), 4)}/dedace)')
ax.plot(ASI.index, m1*ASI.index+b1, color='black', linestyle=':', label=f'trend_winter ({round(float(10*m1), 4)}/dedace)')
ax.bar(ASI.index, ASI['winter'], color='darkturquoise', edgecolor='black')
ax.bar(ASI.index, ASI['all'], label='all months', color='orange', edgecolor='black')
ax.bar(ASI.index, np.where((ASI['winter'] < ASI['all']), ASI['winter'], 0), color='darkturquoise', edgecolor='black', label='only winter months')
ax.legend(fontsize=16, ncol=2)
ax.set_title(station_name, fontsize=20)
ax.tick_params(labelsize=14)
ax.set_ylim((0,2))
ax.set_xlabel('year', fontsize=18)
ax.set_ylabel('annual storm index (per day)', fontsize=18)

plt.savefig('../Figures/'+str(station_name)+'_asi', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Inter-annual variability

# %%
window=3
ASI_std = ASI.rolling(window=window, center=True).std()

# Plot
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(ASI_std.index, ASI_std['winter'], marker='*', linestyle='-', label='Winter', color='deepskyblue')
ax.plot(ASI_std.index, ASI_std['all'], marker='^', linestyle='-', label='All', color='slategray')
ax.plot(ASI_std.index, ASI_std['summer'], marker='o', linestyle='-', label='Summer', color='orange')

ax.set_ylabel(str(window)+'-year Rolling Std Dev', fontsize=14)
ax.set_xlabel('Year', fontsize=14)
ax.legend(fontsize=16, ncol=1)
ax.set_title(station_name, fontsize=20)
ax.tick_params(labelsize=14)
ax.grid(True)

plt.savefig('../Figures/'+str(station_name)+'_'+str(window)+'year_std', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Monthly Storm Index

# %%
# Plotting the heatmap
fig, ax = plt.subplots(1,1,figsize=(10, 6))
cmap = sns.color_palette('viridis', as_cmap=True) #"coolwarm"
cmap.set_bad(color='black')
sns.heatmap(MSI.T, cmap=cmap, annot=False, cbar=True)

# formatting
colorbar = ax.collections[0].colorbar
colorbar.set_label('Fraction of Mean Storm Strength per Day', fontsize=14)
ax.set_title(station_name, fontsize=24)
ax.set_xlabel('')
ax.set_ylabel('')
ax.tick_params(labelsize=12)
ax.set_xticklabels(month_start_labels, rotation=0)

plt.show()

# %% [markdown]
# ### Center of Storminess

# %%
fig, ax = plt.subplots(1,1,figsize=(10, 6))

# Plotting the heatmap
cmap = sns.color_palette('viridis', as_cmap=True) #"coolwarm"
cmap.set_bad(color='black')
sns.heatmap(MSI.T, cmap=cmap, annot=False, cbar=True, alpha=1, ax=ax)
print(ax.get_xticks())

# Plotting dots
x_positions = np.interp(CoS_df['cos'], np.arange(1, 366), np.linspace(0.5, len(month_start_labels)-0.5, 365))
print(x_positions)
ax.scatter(x_positions, years-start_year+0.5, color='red', s=50, edgecolor='black')

# formatting
colorbar = ax.collections[0].colorbar
colorbar.set_label('Fraction of Mean Storm Strength per Day', fontsize=14)
ax.set_title(station_name, fontsize=24)
ax.set_xlabel('')
ax.set_ylabel('')
ax.tick_params(labelsize=14)
ax.set_xticklabels(month_start_labels, rotation=0)
ax.invert_yaxis()

plt.savefig('../Figures/'+str(station_name)+'_msi', bbox_inches='tight')
plt.show()
# Out:
# [ 0.5  1.5  2.5  3.5  4.5  5.5  6.5  7.5  8.5  9.5 10.5 11.5]
# [       nan 6.07305227 6.46841418 6.4391549  5.6203293  7.12804399
#  5.52077464 5.56531182 6.65234606 5.94346006 4.30287998 7.09086836
#  6.72682421 7.39745387 5.45684747 5.47497302 6.14544774 6.4432208
#  5.50349228 6.15053837 5.59993881 6.66022747 6.15695398 6.62798819
#  6.77234608 5.34522268 6.08682637 5.49033743 7.11435636 6.13732578
#         nan 6.52194759 6.12663031 5.28997322 5.84742486 6.67788616
#  4.65627414 6.27582101 6.52251366 5.60838462 4.65293051 5.64507283
#  6.45637247 6.32864755 6.58641223 5.11921449 6.16513942 5.86922534
#  5.10255901 5.06905298 6.68484325 6.67241463 4.97041639 6.13841173
#  5.6215345  6.15335249 6.48074805 5.44346764 6.41787522 6.69670205
#  5.14558545]

# %%
CoS_df.index = CoS_df['years']
m, b, p_m, p_b = si.linear_fit(CoS_df, 'cos')
print(m, b, p_m, p_b)
print(f"Shift of center of storminess in days per year: {m}")
# Out:
# -0.18676692206281675 556.0925102981033 0.26735449952642076 0.09998431747488734
# Shift of center of storminess in days per year: -0.18676692206281675

# %%
bell_parameters.index = bell_parameters['years']
m, b, p_m, p_b = si.linear_fit(bell_parameters, 'amplitude')
print(m, b, p_m, p_b)
print(f"The shift in amplitude per year is: {m}")
m, b, p_m, p_b = si.linear_fit(bell_parameters, 'mu')
print(m, b, p_m, p_b)
print(f"The shift in the central day of the storminess distribution per year is: {m}")
m, b, p_m, p_b = si.linear_fit(bell_parameters, 'sigma')
print(m, b, p_m, p_b)
print(f"The shift in the width of the storminess distribution per year is: {m}")
# Out:
# 0.01234040850534468 -22.024502536627455 0.5833005650760867 0.6234347955507649
# The shift in amplitude per year is: 0.01234040850534468
# -0.07236478557971782 329.02939564514145 0.7673543258558129 0.5007596328099497
# The shift in the central day of the storminess distribution per year is: -0.07236478557971782
# -0.4303896115127477 930.1797017070921 0.25420923312607724 0.21711560382990602
# The shift in the width of the storminess distribution per year is: -0.4303896115127477

# %%
TP['year'] = TP.index.year

non_nan_temperature = TP.groupby(['year'])[t_column_name].count()
temp = TP.groupby(['year'])[t_column_name].sum() / non_nan_temperature
invalid_years_temperature = non_nan_temperature[non_nan_temperature < 335].index

non_nan_pressure = TP.groupby(['year'])[p_column_name].count()
pres = TP.groupby(['year'])[p_column_name].sum() / non_nan_pressure
invalid_years_pressure = non_nan_pressure[non_nan_pressure < 335].index

del TP['year']

# %%
# Setup
cols = ['T_anom', 'P_anom']
xlabels = ['Temperature anomaly depth (°C)', 'Pressure anomaly depth (hPa)']

# Prepare figure and axes
fig, axes = plt.subplots(1, 2, figsize=(10, 6), sharey=True)
fig.subplots_adjust(left=0.15, right=0.85, wspace=0.05)

# Store contour sets to determine shared color scale
all_Z = []

for i, (col, ax) in enumerate(zip(cols, axes)):
    df = df_anomalies[[col]].dropna().copy()
    df['Year'] = df.index.year

    # Use linear bins (change to log if desired)
    vals = df[col].dropna()
    bins = np.linspace(vals.min(), vals.max(), 50)
    #vals = df[col][df[col] > 0]
    #bins = np.logspace(np.log10(vals.min()), np.log10(vals.max()), 50)
    df['AnomalyBin'] = pd.cut(df[col], bins=bins)

    # Count occurrences
    heatmap = df.groupby(['Year', 'AnomalyBin'])[col].count().unstack(fill_value=0)

    # Build grid
    Z = heatmap.values
    all_Z.append(Z)

# Find global Z min and max for shared contour levels
global_min = min(Z.min() for Z in all_Z)
global_max = max(Z.max() for Z in all_Z)
levels = np.arange(global_min, global_max + 1)

# Plot each
for i, (col, ax, Z) in enumerate(zip(cols, axes, all_Z)):
    df = df_anomalies[[col]].dropna().copy()
    df['Year'] = df.index.year
    
    # Use linear bins (change to log if desired)
    vals = df[col].dropna()
    bins = np.linspace(vals.min(), vals.max(), 50)
    #vals = df[col][df[col] > 0]
    #bins = np.logspace(np.log10(vals.min()), np.log10(vals.max()), 50)
    bin_edges = bins
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    df['AnomalyBin'] = pd.cut(df[col], bins=bins)

    heatmap = df.groupby(['Year', 'AnomalyBin'])[col].count().unstack(fill_value=0)
    X, Y = np.meshgrid(bin_centers, heatmap.index.values)

    cs = ax.contourf(X, Y, Z, levels=levels, cmap='viridis')

    # White out invalid years
    xlim = ax.get_xlim()
    for year in invalid_years_temperature:
        if year in years:
            ax.fill_betweenx([year - 0.5, year + 0.5], *xlim, color='white')
    ax.set_xlim(xlim)

    # Labels
    ax.set_xlabel(xlabels[i], fontsize=14)
    ax.set_ylim((1964, 2024))
    ax.tick_params(labelsize=14)
    ax.set_yticks(heatmap.index.values[::5])
    ax.set_yticklabels(heatmap.index.values[::5])

axes[0].set_ylabel('Year', fontsize=16)
axes[1].yaxis.tick_right()
axes[1].yaxis.set_label_position("right")

fig.suptitle(str(station_name), fontsize=24)

# Shared colorbar (placed to the right of subplots)
cbar_ax = fig.add_axes([0.9, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
cbar = fig.colorbar(cs, cax=cbar_ax)
cbar.set_label('Count (days per year)', fontsize=14)
cbar.set_ticks(levels[::2])

plt.savefig(f'../Figures/{station_name}_temp_pres_anom_LINEAR.png', bbox_inches='tight')
plt.show()

# %%
# Setup
cols = ['T_anom', 'P_anom']
xlabels = ['Temperature anomaly depth (°C)', 'Pressure anomaly depth (hPa)']

# Prepare figure and axes
fig, axes = plt.subplots(1, 2, figsize=(10, 6), sharey=True)
fig.subplots_adjust(left=0.15, right=0.85, wspace=0.05)

# Store contour sets to determine shared color scale
all_Z = []
for i, (col, ax) in enumerate(zip(cols, axes)):
    df = df_anomalies[[col]].dropna().copy()
    df['Year'] = df.index.year
    # Use linear bins (change to log if desired)
    #vals = df[col].dropna()
    #bins = np.linspace(vals.min(), vals.max(), 50)
    vals = df[col][df[col] > 0]
    bins = np.logspace(np.log10(vals.min()), np.log10(vals.max()), 50)
    df['AnomalyBin'] = pd.cut(df[col], bins=bins)
    # Count occurrences
    heatmap = df.groupby(['Year', 'AnomalyBin'])[col].count().unstack(fill_value=0)
    # Build grid
    Z = heatmap.values
    all_Z.append(Z)

global_min = 0
global_max = 15 # for non-simultneous anomalies: 43
levels = np.arange(global_min, global_max + 1)

# Plot each
for i, (col, ax, Z) in enumerate(zip(cols, axes, all_Z)):
    df = df_anomalies[[col]].dropna().copy()
    df['Year'] = df.index.year
    
    # Use linear bins (change to log if desired)
    #vals = df[col].dropna()
    #bins = np.linspace(vals.min(), vals.max(), 50)
    vals = df[col][df[col] > 0]
    bins = np.logspace(np.log10(vals.min()), np.log10(vals.max()), 50)
    bin_edges = bins
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    df['AnomalyBin'] = pd.cut(df[col], bins=bins)

    heatmap = df.groupby(['Year', 'AnomalyBin'])[col].count().unstack(fill_value=0)
    X, Y = np.meshgrid(bin_centers, heatmap.index.values)

    cs = ax.contourf(X, Y, Z, levels=levels, cmap='viridis', extend='max')
    #cl = ax.contour(X, Y, Z, levels=levels[::5], colors='black', linewidths=0.5)
    #ax.clabel(cl, fmt='%d', fontsize=8)

    # White out invalid years
    xlim = ax.get_xlim()
    for year in invalid_years_temperature:
        if year in years:
            ax.fill_betweenx([year - 0.5, year + 0.5], *xlim, color='white')
    ax.set_xlim(xlim)

    # Labels
    ax.set_xlabel(xlabels[i], fontsize=14)
    ax.set_ylim((1964, 2024))
    ax.tick_params(labelsize=14)
    ax.set_yticks(heatmap.index.values[::5])
    ax.set_yticklabels(heatmap.index.values[::5])

axes[0].set_ylabel('Year', fontsize=16)
axes[1].yaxis.tick_right()
axes[1].yaxis.set_label_position("right")

fig.suptitle(str(station_name), fontsize=24)

# Shared colorbar (placed to the right of subplots) only for Scott Base
if station_name == 'ScottBase':
    cbar_ax = fig.add_axes([0.9, 0.075, 0.02, 0.85])  # [left, bottom, width, height]
    cbar = fig.colorbar(cs, cax=cbar_ax)
    cbar.set_label('Count (days per year)', fontsize=14)
    cbar.set_ticks(levels[::2])

plt.savefig(f'../Figures/{station_name}_temp_pres_anom.png', bbox_inches='tight')
plt.show()
