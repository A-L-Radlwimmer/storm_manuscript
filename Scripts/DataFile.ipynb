# %% [markdown]
# # Create File with Storm Indexes, Temperatures, and Pressures of All Stations

# %%
import storm_indices as si
import pandas as pd

# %%
TP = pd.read_csv('../Data/scottbase/scottbase.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['Mean Temperature [Deg C]', 'Mean sea level pressure [Hpa]']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'Mean Temperature [Deg C]', 'Mean sea level pressure [Hpa]', 'SI')
TP = TP.rename(columns={'Mean Temperature [Deg C]': 'SB_T', 'Mean sea level pressure [Hpa]': 'SB_P', 'SI': 'SB_SI'})
SB = TP.copy()

TP = pd.read_csv('../Data/lettau/lettau.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'LE_T', 'pressure': 'LE_P', 'SI': 'LE_SI'})
LE = TP.copy()

TP = pd.read_csv('../Data/margaret/margaret.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'MR_T', 'pressure': 'MR_P', 'SI': 'MR_SI'})
MR = TP.copy()

TP = pd.read_csv('../Data/gill/gill.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'GL_T', 'pressure': 'GL_P', 'SI': 'GL_SI'})
GL = TP.copy()

TP = pd.read_csv('../Data/schwerdtfeger/schwerdtfeger.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'SW_T', 'pressure': 'SW_P', 'SI': 'SW_SI'})
SW = TP.copy()

TP = pd.read_csv('../Data/marilyn/marilyn.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'MY_T', 'pressure': 'MY_P', 'SI': 'MY_SI'})
MY = TP.copy()

TP = pd.read_csv('../Data/ferrell/ferrell.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'FR_T', 'pressure': 'FR_P', 'SI': 'FR_SI'})
FR = TP.copy()

TP = pd.read_csv('../Data/laurie2/laurie2.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'LR_T', 'pressure': 'LR_P', 'SI': 'LR_SI'})
LR = TP.copy()

TP = pd.read_csv('../Data/marblepoint/marblepoint.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'MP_T', 'pressure': 'MP_P', 'SI': 'MP_SI'})
MP = TP.copy()

TP = pd.read_csv('../Data/arelis/arelis.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature_C', 'pressure_hPa']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature_C', 'pressure_hPa', 'SI')
TP = TP.rename(columns={'temperature_C': 'AR_T', 'pressure_hPa': 'AR_P', 'SI': 'AR_SI'})
AR = TP.copy()

TP = pd.read_csv('../Data/manuela/manuela.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature', 'pressure']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature', 'pressure', 'SI')
TP = TP.rename(columns={'temperature': 'MN_T', 'pressure': 'MN_P', 'SI': 'MN_SI'})
MN = TP.copy()

TP = pd.read_csv('../Data/alessandra/alessandra.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature_C', 'pressure_hPa']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature_C', 'pressure_hPa', 'SI')
TP = TP.rename(columns={'temperature_C': 'AL_T', 'pressure_hPa': 'AL_P', 'SI': 'AL_SI'})
AL = TP.copy()

TP = pd.read_csv('../Data/silvia/silvia.csv')
TP['DateTime'] = pd.to_datetime(TP['DateTime'],format='%Y-%m-%d')
TP.index = TP['DateTime']
del TP['DateTime']
TP = TP[['temperature_C', 'pressure_hPa']]
TP = TP[~TP.index.isna()]
TP = si.compute_si(TP, 'temperature_C', 'pressure_hPa', 'SI')
TP = TP.rename(columns={'temperature_C': 'SV_T', 'pressure_hPa': 'SV_P', 'SI': 'SV_SI'})
SV = TP.copy()

# %%
df = pd.concat([SB, LE, MR, GL, SW, MY, FR, LR, MP, AR, MN, AL, SV], axis=1)
df = df.sort_index() # just to make sure
df = df.loc[:'2024-12-31']
df
# Out:
#             SB_T    SB_P     SB_SI      LE_T        LE_P  LE_SI      MR_T  \
# DateTime
# 1964-09-30   NaN  1005.0  0.000000       NaN         NaN    NaN       NaN
# 1964-10-01 -24.6   997.6  0.000000       NaN         NaN    NaN       NaN
# 1964-10-02 -25.8   997.4  0.000000       NaN         NaN    NaN       NaN
# 1964-10-03 -28.3   989.1  0.304381       NaN         NaN    NaN       NaN
# 1964-10-04 -26.2   976.2  0.304381       NaN         NaN    NaN       NaN
# ...          ...     ...       ...       ...         ...    ...       ...
# 2024-12-27  -3.4   989.1  0.000000 -5.825000  985.512500    0.0 -6.939130
# 2024-12-28  -4.7   993.9  0.000000 -5.837500  986.275000    0.0 -8.225000
# 2024-12-29  -2.9   989.5  0.000000 -5.333333  982.695833    0.0 -6.395833
# 2024-12-30  -1.2   985.8  0.000000 -5.458333  978.491667    0.0 -7.337500
# 2024-12-31  -0.9   989.3  0.000000 -4.966667  979.675000    0.0 -6.750000
#
# ...

# %%
df.to_csv('../Data/si_file.csv')
