# %% [markdown]
# ## Storm indices for all AWS in Wang et al., 2022

# %%
import pandas as pd

# %%
t_column_name = 'Temperature(¡æ)'
p_column_name = 'Pressure(hPa)'

TP = pd.read_csv('../../Data/alessandra/Alessandra_3h.csv', header=0, encoding='latin1')
TP['DateTime'] = pd.to_datetime(dict(year=TP['Year'], month=TP['Month'], day=TP['Day'], hour=TP['Three-hourly observation time(UTC)']))
TP.index = TP['DateTime']
TP = TP[[t_column_name, p_column_name]]
TP.rename(columns={t_column_name: 'temperature_C', p_column_name: 'pressure_hPa'}, inplace=True)

#TP.to_csv(output_path+station_clean+'_SI.csv')
TP
# Out:
#                      temperature_C  pressure_hPa
# DateTime
# 1987-01-01 00:00:00            NaN           NaN
# 1987-01-01 03:00:00            NaN           NaN
# 1987-01-01 06:00:00            NaN           NaN
# 1987-01-01 09:00:00            NaN           NaN
# 1987-01-01 12:00:00            NaN           NaN
# ...                            ...           ...
# 2021-11-05 09:00:00            NaN           NaN
# 2021-11-05 12:00:00            NaN           NaN
# 2021-11-05 15:00:00            NaN           NaN
# 2021-11-05 18:00:00            NaN           NaN
# 2021-11-05 21:00:00            NaN           NaN
#
# [101824 rows x 2 columns]
