# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import csv
import glob as gl
import tqdm
import pandas as pd
import numpy as np

# %%
def prevailing_wind_direction(wind_dir_series):
    rad = np.deg2rad(wind_dir_series)
    sin_mean = np.nanmean(np.sin(rad))
    cos_mean = np.nanmean(np.cos(rad))
    mean_dir_rad = np.arctan2(sin_mean, cos_mean)
    mean_dir_deg = (np.rad2deg(mean_dir_rad)) % 360
    return mean_dir_deg

# %%
def download_file(file_url, download_dir):
    """Download the file from the specified URL."""
    local_filename = os.path.join(download_dir, os.path.basename(file_url))
    with requests.get(file_url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192): 
                f.write(chunk)
    print(f"Downloaded: {local_filename}")
    return os.path.basename(file_url)

def scrape_and_download(url, file_pattern, download_dir):
    """Scrape the website and download files matching the pattern."""
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all links on the webpage and download the matching files
    for link in soup.find_all('a', href=True):
        file_url = link['href']
        if file_pattern.match(file_url):
            # Prepend the base URL if necessary
            if not file_url.startswith('http'):
                file_url = url + file_url
            # Download the file
            download_file(file_url, download_dir)
            
def download_vito(year):
    # Directory where you want to save the downloaded files
    download_dir = '../../Data/capebird'
    if not os.path.exists(download_dir):
        os.makedirs(download_dir)
    
    # Pattern to match the file names
    file_pattern = re.compile(r'cbd.*q1h\.txt')

    # Find data online
    url = 'https://amrc.ssec.wisc.edu/data/ftp/pub/aws/q1h/' + str(year) + '/'

    scrape_and_download(url, file_pattern, download_dir)

# %%
for year in [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]:
    download_vito(year)
# Out:
# Downloaded: ../../Data/capebird\cbd200109q1h.txt
# Downloaded: ../../Data/capebird\cbd200110q1h.txt
# Downloaded: ../../Data/capebird\cbd200111q1h.txt
# Downloaded: ../../Data/capebird\cbd200112q1h.txt
# Downloaded: ../../Data/capebird\cbd200201q1h.txt
# Downloaded: ../../Data/capebird\cbd200202q1h.txt
# Downloaded: ../../Data/capebird\cbd200203q1h.txt
# Downloaded: ../../Data/capebird\cbd200204q1h.txt
# Downloaded: ../../Data/capebird\cbd200205q1h.txt
# Downloaded: ../../Data/capebird\cbd200206q1h.txt
# Downloaded: ../../Data/capebird\cbd200207q1h.txt
# Downloaded: ../../Data/capebird\cbd200208q1h.txt
# Downloaded: ../../Data/capebird\cbd200209q1h.txt
# Downloaded: ../../Data/capebird\cbd200210q1h.txt
# Downloaded: ../../Data/capebird\cbd200211q1h.txt
# Downloaded: ../../Data/capebird\cbd200212q1h.txt
# Downloaded: ../../Data/capebird\cbd200301q1h.txt
# Downloaded: ../../Data/capebird\cbd200302q1h.txt
# Downloaded: ../../Data/capebird\cbd200303q1h.txt
# Downloaded: ../../Data/capebird\cbd200304q1h.txt
# Downloaded: ../../Data/capebird\cbd200305q1h.txt
# Downloaded: ../../Data/capebird\cbd200306q1h.txt
# Downloaded: ../../Data/capebird\cbd200307q1h.txt
# Downloaded: ../../Data/capebird\cbd200308q1h.txt
# Downloaded: ../../Data/capebird\cbd200309q1h.txt
# Downloaded: ../../Data/capebird\cbd200310q1h.txt
# Downloaded: ../../Data/capebird\cbd200311q1h.txt
# Downloaded: ../../Data/capebird\cbd200312q1h.txt
# Downloaded: ../../Data/capebird\cbd200401q1h.txt
# Downloaded: ../../Data/capebird\cbd200402q1h.txt
# Downloaded: ../../Data/capebird\cbd200403q1h.txt
# Downloaded: ../../Data/capebird\cbd200404q1h.txt
# Downloaded: ../../Data/capebird\cbd200405q1h.txt
# Downloaded: ../../Data/capebird\cbd200406q1h.txt
# Downloaded: ../../Data/capebird\cbd200407q1h.txt
# Downloaded: ../../Data/capebird\cbd200408q1h.txt
# Downloaded: ../../Data/capebird\cbd200409q1h.txt
# Downloaded: ../../Data/capebird\cbd200410q1h.txt
# Downloaded: ../../Data/capebird\cbd200411q1h.txt
# Downloaded: ../../Data/capebird\cbd200412q1h.txt
# Downloaded: ../../Data/capebird\cbd200501q1h.txt
# Downloaded: ../../Data/capebird\cbd200502q1h.txt
# Downloaded: ../../Data/capebird\cbd200503q1h.txt
# Downloaded: ../../Data/capebird\cbd200504q1h.txt
# Downloaded: ../../Data/capebird\cbd200505q1h.txt
# Downloaded: ../../Data/capebird\cbd200506q1h.txt
# Downloaded: ../../Data/capebird\cbd200507q1h.txt
# Downloaded: ../../Data/capebird\cbd200508q1h.txt
# Downloaded: ../../Data/capebird\cbd200509q1h.txt
# Downloaded: ../../Data/capebird\cbd200510q1h.txt
# Downloaded: ../../Data/capebird\cbd200511q1h.txt
# Downloaded: ../../Data/capebird\cbd200512q1h.txt
# Downloaded: ../../Data/capebird\cbd200601q1h.txt
# Downloaded: ../../Data/capebird\cbd200602q1h.txt
# Downloaded: ../../Data/capebird\cbd200603q1h.txt
# Downloaded: ../../Data/capebird\cbd200604q1h.txt
# Downloaded: ../../Data/capebird\cbd200605q1h.txt
# Downloaded: ../../Data/capebird\cbd200606q1h.txt
# Downloaded: ../../Data/capebird\cbd200607q1h.txt
# Downloaded: ../../Data/capebird\cbd200608q1h.txt
# Downloaded: ../../Data/capebird\cbd200609q1h.txt
# Downloaded: ../../Data/capebird\cbd200610q1h.txt
# Downloaded: ../../Data/capebird\cbd200611q1h.txt
# Downloaded: ../../Data/capebird\cbd200612q1h.txt
# Downloaded: ../../Data/capebird\cbd200701q1h.txt
# Downloaded: ../../Data/capebird\cbd200702q1h.txt
# Downloaded: ../../Data/capebird\cbd200703q1h.txt
# Downloaded: ../../Data/capebird\cbd200704q1h.txt
# Downloaded: ../../Data/capebird\cbd200705q1h.txt
# Downloaded: ../../Data/capebird\cbd200706q1h.txt
# Downloaded: ../../Data/capebird\cbd200707q1h.txt
# Downloaded: ../../Data/capebird\cbd200708q1h.txt
# Downloaded: ../../Data/capebird\cbd200709q1h.txt
# Downloaded: ../../Data/capebird\cbd200710q1h.txt
# Downloaded: ../../Data/capebird\cbd200711q1h.txt
# Downloaded: ../../Data/capebird\cbd200712q1h.txt
# Downloaded: ../../Data/capebird\cbd200801q1h.txt
# Downloaded: ../../Data/capebird\cbd200802q1h.txt
# Downloaded: ../../Data/capebird\cbd200803q1h.txt
# Downloaded: ../../Data/capebird\cbd200804q1h.txt
# Downloaded: ../../Data/capebird\cbd200805q1h.txt
# Downloaded: ../../Data/capebird\cbd200806q1h.txt
# Downloaded: ../../Data/capebird\cbd200807q1h.txt
# Downloaded: ../../Data/capebird\cbd200808q1h.txt
# Downloaded: ../../Data/capebird\cbd200809q1h.txt
# Downloaded: ../../Data/capebird\cbd200810q1h.txt
# Downloaded: ../../Data/capebird\cbd200811q1h.txt
# Downloaded: ../../Data/capebird\cbd200812q1h.txt
# Downloaded: ../../Data/capebird\cbd200801q1h.txt
# Downloaded: ../../Data/capebird\cbd200802q1h.txt
# Downloaded: ../../Data/capebird\cbd200803q1h.txt
# Downloaded: ../../Data/capebird\cbd200804q1h.txt
# Downloaded: ../../Data/capebird\cbd200805q1h.txt
# Downloaded: ../../Data/capebird\cbd200806q1h.txt
# Downloaded: ../../Data/capebird\cbd200807q1h.txt
# Downloaded: ../../Data/capebird\cbd200808q1h.txt
# Downloaded: ../../Data/capebird\cbd200809q1h.txt
# Downloaded: ../../Data/capebird\cbd200810q1h.txt
# Downloaded: ../../Data/capebird\cbd200811q1h.txt
# Downloaded: ../../Data/capebird\cbd200812q1h.txt
# Downloaded: ../../Data/capebird\cbd200901q1h.txt
# Downloaded: ../../Data/capebird\cbd200902q1h.txt
# Downloaded: ../../Data/capebird\cbd200903q1h.txt
# Downloaded: ../../Data/capebird\cbd200904q1h.txt
# Downloaded: ../../Data/capebird\cbd200905q1h.txt
# Downloaded: ../../Data/capebird\cbd200906q1h.txt
# Downloaded: ../../Data/capebird\cbd200907q1h.txt
# Downloaded: ../../Data/capebird\cbd200908q1h.txt
# Downloaded: ../../Data/capebird\cbd200909q1h.txt
# Downloaded: ../../Data/capebird\cbd200910q1h.txt
# Downloaded: ../../Data/capebird\cbd200911q1h.txt
# Downloaded: ../../Data/capebird\cbd200912q1h.txt
# Downloaded: ../../Data/capebird\cbd201001q1h.txt
# Downloaded: ../../Data/capebird\cbd201002q1h.txt
# Downloaded: ../../Data/capebird\cbd201003q1h.txt
# Downloaded: ../../Data/capebird\cbd201004q1h.txt
# Downloaded: ../../Data/capebird\cbd201005q1h.txt
# Downloaded: ../../Data/capebird\cbd201006q1h.txt
# Downloaded: ../../Data/capebird\cbd201007q1h.txt
# Downloaded: ../../Data/capebird\cbd201008q1h.txt
# Downloaded: ../../Data/capebird\cbd201009q1h.txt
# Downloaded: ../../Data/capebird\cbd201010q1h.txt
# Downloaded: ../../Data/capebird\cbd201011q1h.txt
# Downloaded: ../../Data/capebird\cbd201012q1h.txt
# Downloaded: ../../Data/capebird\cbd201101q1h.txt
# Downloaded: ../../Data/capebird\cbd201102q1h.txt
# Downloaded: ../../Data/capebird\cbd201103q1h.txt
# Downloaded: ../../Data/capebird\cbd201104q1h.txt
# Downloaded: ../../Data/capebird\cbd201105q1h.txt
# Downloaded: ../../Data/capebird\cbd201106q1h.txt
# Downloaded: ../../Data/capebird\cbd201107q1h.txt
# Downloaded: ../../Data/capebird\cbd201108q1h.txt
# Downloaded: ../../Data/capebird\cbd201109q1h.txt
# Downloaded: ../../Data/capebird\cbd201110q1h.txt
# Downloaded: ../../Data/capebird\cbd201111q1h.txt
# Downloaded: ../../Data/capebird\cbd201112q1h.txt
# Downloaded: ../../Data/capebird\cbd201201q1h.txt
# Downloaded: ../../Data/capebird\cbd201202q1h.txt
# Downloaded: ../../Data/capebird\cbd201203q1h.txt
# Downloaded: ../../Data/capebird\cbd201206q1h.txt
# Downloaded: ../../Data/capebird\cbd201207q1h.txt
# Downloaded: ../../Data/capebird\cbd201208q1h.txt
# Downloaded: ../../Data/capebird\cbd201210q1h.txt
# Downloaded: ../../Data/capebird\cbd201211q1h.txt
# Downloaded: ../../Data/capebird\cbd201212q1h.txt
# Downloaded: ../../Data/capebird\cbd201301q1h.txt
# Downloaded: ../../Data/capebird\cbd201302q1h.txt
# Downloaded: ../../Data/capebird\cbd201303q1h.txt
# Downloaded: ../../Data/capebird\cbd201304q1h.txt
# Downloaded: ../../Data/capebird\cbd201305q1h.txt
# Downloaded: ../../Data/capebird\cbd201306q1h.txt
# Downloaded: ../../Data/capebird\cbd201307q1h.txt
# Downloaded: ../../Data/capebird\cbd201308q1h.txt
# Downloaded: ../../Data/capebird\cbd201309q1h.txt
# Downloaded: ../../Data/capebird\cbd201310q1h.txt
# Downloaded: ../../Data/capebird\cbd201311q1h.txt
# Downloaded: ../../Data/capebird\cbd201312q1h.txt
# Downloaded: ../../Data/capebird\cbd201401q1h.txt
# Downloaded: ../../Data/capebird\cbd201402q1h.txt
# Downloaded: ../../Data/capebird\cbd201403q1h.txt
# Downloaded: ../../Data/capebird\cbd201404q1h.txt
# Downloaded: ../../Data/capebird\cbd201405q1h.txt
# Downloaded: ../../Data/capebird\cbd201406q1h.txt
# Downloaded: ../../Data/capebird\cbd201407q1h.txt
# Downloaded: ../../Data/capebird\cbd201408q1h.txt
# Downloaded: ../../Data/capebird\cbd201409q1h.txt
# Downloaded: ../../Data/capebird\cbd201410q1h.txt
# Downloaded: ../../Data/capebird\cbd201411q1h.txt
# Downloaded: ../../Data/capebird\cbd201412q1h.txt
# Downloaded: ../../Data/capebird\cbd201501q1h.txt
# Downloaded: ../../Data/capebird\cbd201502q1h.txt
# Downloaded: ../../Data/capebird\cbd201503q1h.txt
# Downloaded: ../../Data/capebird\cbd201504q1h.txt
# Downloaded: ../../Data/capebird\cbd201505q1h.txt
# Downloaded: ../../Data/capebird\cbd201506q1h.txt
# Downloaded: ../../Data/capebird\cbd201507q1h.txt
# Downloaded: ../../Data/capebird\cbd201508q1h.txt
# Downloaded: ../../Data/capebird\cbd201509q1h.txt
# Downloaded: ../../Data/capebird\cbd201510q1h.txt
# Downloaded: ../../Data/capebird\cbd201511q1h.txt
# Downloaded: ../../Data/capebird\cbd201512q1h.txt
# Downloaded: ../../Data/capebird\cbd201601q1h.txt
# Downloaded: ../../Data/capebird\cbd201602q1h.txt
# Downloaded: ../../Data/capebird\cbd201603q1h.txt
# Downloaded: ../../Data/capebird\cbd201604q1h.txt
# Downloaded: ../../Data/capebird\cbd201605q1h.txt
# Downloaded: ../../Data/capebird\cbd201606q1h.txt
# Downloaded: ../../Data/capebird\cbd201607q1h.txt
# Downloaded: ../../Data/capebird\cbd201608q1h.txt
# Downloaded: ../../Data/capebird\cbd201609q1h.txt
# Downloaded: ../../Data/capebird\cbd201610q1h.txt
# Downloaded: ../../Data/capebird\cbd201611q1h.txt
# Downloaded: ../../Data/capebird\cbd201612q1h.txt
# Downloaded: ../../Data/capebird\cbd201701q1h.txt
# Downloaded: ../../Data/capebird\cbd201702q1h.txt
# Downloaded: ../../Data/capebird\cbd201703q1h.txt
# Downloaded: ../../Data/capebird\cbd201704q1h.txt
# Downloaded: ../../Data/capebird\cbd201705q1h.txt
# Downloaded: ../../Data/capebird\cbd201706q1h.txt
# Downloaded: ../../Data/capebird\cbd201707q1h.txt
# Downloaded: ../../Data/capebird\cbd201708q1h.txt
# Downloaded: ../../Data/capebird\cbd201709q1h.txt
# Downloaded: ../../Data/capebird\cbd201710q1h.txt
# Downloaded: ../../Data/capebird\cbd201711q1h.txt
# Downloaded: ../../Data/capebird\cbd201712q1h.txt
# Downloaded: ../../Data/capebird\cbd201801q1h.txt
# Downloaded: ../../Data/capebird\cbd201802q1h.txt
# Downloaded: ../../Data/capebird\cbd201803q1h.txt
# Downloaded: ../../Data/capebird\cbd201804q1h.txt
# Downloaded: ../../Data/capebird\cbd201805q1h.txt
# Downloaded: ../../Data/capebird\cbd201806q1h.txt
# Downloaded: ../../Data/capebird\cbd201807q1h.txt
# Downloaded: ../../Data/capebird\cbd201808q1h.txt
# Downloaded: ../../Data/capebird\cbd201810q1h.txt
# Downloaded: ../../Data/capebird\cbd201811q1h.txt
# Downloaded: ../../Data/capebird\cbd201812q1h.txt
# Downloaded: ../../Data/capebird\cbd201901q1h.txt
# Downloaded: ../../Data/capebird\cbd201902q1h.txt
# Downloaded: ../../Data/capebird\cbd201903q1h.txt
# Downloaded: ../../Data/capebird\cbd201904q1h.txt
# Downloaded: ../../Data/capebird\cbd201905q1h.txt
# Downloaded: ../../Data/capebird\cbd201906q1h.txt
# Downloaded: ../../Data/capebird\cbd201907q1h.txt
# Downloaded: ../../Data/capebird\cbd201908q1h.txt
# Downloaded: ../../Data/capebird\cbd201909q1h.txt
# Downloaded: ../../Data/capebird\cbd201910q1h.txt
# Downloaded: ../../Data/capebird\cbd201911q1h.txt
# Downloaded: ../../Data/capebird\cbd201912q1h.txt
# Downloaded: ../../Data/capebird\cbd202001q1h.txt
# Downloaded: ../../Data/capebird\cbd202002q1h.txt
# Downloaded: ../../Data/capebird\cbd202003q1h.txt
# Downloaded: ../../Data/capebird\cbd202004q1h.txt
# Downloaded: ../../Data/capebird\cbd202005q1h.txt
# Downloaded: ../../Data/capebird\cbd202006q1h.txt
# Downloaded: ../../Data/capebird\cbd202007q1h.txt
# Downloaded: ../../Data/capebird\cbd202008q1h.txt
# Downloaded: ../../Data/capebird\cbd202009q1h.txt
# Downloaded: ../../Data/capebird\cbd202010q1h.txt
# Downloaded: ../../Data/capebird\cbd202011q1h.txt
# Downloaded: ../../Data/capebird\cbd202012q1h.txt
# Downloaded: ../../Data/capebird\cbd202101q1h.txt
# Downloaded: ../../Data/capebird\cbd202102q1h.txt
# Downloaded: ../../Data/capebird\cbd202103q1h.txt
# Downloaded: ../../Data/capebird\cbd202104q1h.txt
# Downloaded: ../../Data/capebird\cbd202105q1h.txt
# Downloaded: ../../Data/capebird\cbd202106q1h.txt
# Downloaded: ../../Data/capebird\cbd202107q1h.txt
# Downloaded: ../../Data/capebird\cbd202108q1h.txt
# Downloaded: ../../Data/capebird\cbd202109q1h.txt
# Downloaded: ../../Data/capebird\cbd202110q1h.txt
# Downloaded: ../../Data/capebird\cbd202111q1h.txt
# Downloaded: ../../Data/capebird\cbd202112q1h.txt
# Downloaded: ../../Data/capebird\cbd202201q1h.txt
# Downloaded: ../../Data/capebird\cbd202202q1h.txt
# Downloaded: ../../Data/capebird\cbd202203q1h.txt
# Downloaded: ../../Data/capebird\cbd202204q1h.txt
# Downloaded: ../../Data/capebird\cbd202205q1h.txt
# Downloaded: ../../Data/capebird\cbd202206q1h.txt
# Downloaded: ../../Data/capebird\cbd202207q1h.txt
# Downloaded: ../../Data/capebird\cbd202208q1h.txt
# Downloaded: ../../Data/capebird\cbd202209q1h.txt
# Downloaded: ../../Data/capebird\cbd202210q1h.txt
# Downloaded: ../../Data/capebird\cbd202211q1h.txt
# Downloaded: ../../Data/capebird\cbd202212q1h.txt
# Downloaded: ../../Data/capebird\cbd202301q1h.txt
# Downloaded: ../../Data/capebird\cbd202302q1h.txt
# Downloaded: ../../Data/capebird\cbd202303q1h.txt
# Downloaded: ../../Data/capebird\cbd202304q1h.txt
# Downloaded: ../../Data/capebird\cbd202305q1h.txt
# Downloaded: ../../Data/capebird\cbd202306q1h.txt
# Downloaded: ../../Data/capebird\cbd202307q1h.txt
# Downloaded: ../../Data/capebird\cbd202308q1h.txt
# Downloaded: ../../Data/capebird\cbd202309q1h.txt
# Downloaded: ../../Data/capebird\cbd202310q1h.txt
# Downloaded: ../../Data/capebird\cbd202311q1h.txt
# Downloaded: ../../Data/capebird\cbd202312q1h.txt
# Downloaded: ../../Data/capebird\cbd202401q1h.txt
# Downloaded: ../../Data/capebird\cbd202402q1h.txt
# Downloaded: ../../Data/capebird\cbd202403q1h.txt
# Downloaded: ../../Data/capebird\cbd202404q1h.txt
# Downloaded: ../../Data/capebird\cbd202405q1h.txt
# Downloaded: ../../Data/capebird\cbd202406q1h.txt
# Downloaded: ../../Data/capebird\cbd202407q1h.txt
# Downloaded: ../../Data/capebird\cbd202408q1h.txt
# Downloaded: ../../Data/capebird\cbd202409q1h.txt
# Downloaded: ../../Data/capebird\cbd202410q1h.txt
# Downloaded: ../../Data/capebird\cbd202411q1h.txt
# Downloaded: ../../Data/capebird\cbd202412q1h.txt

# %%
path = '../../Data/capebird/'
# create list of file names
aws_files = gl.glob(path + "/cbd*.txt")
# create data frame
columns = ['year', 'doy', 'month', 'day', 'hour', 'temperature', 'pressure', 'wind_speed', 'wind_direction', 'relative_humidity', '?']
content = []
for filename in tqdm.tqdm(aws_files, total=len(aws_files)):
    df = pd.read_csv(filename, names=columns, sep='\s+')
    df.drop(index=df.index[:2], axis=0, inplace=True)
    content.append(df)
vito = pd.concat(content)
# create datetime column and set as index:
vito['DateTime'] = vito['year'].astype(str) + '-' + vito['month'].astype(str) + '-' + vito['day'].astype(str) + ' ' + vito['hour'].astype(str)
vito['DateTime'] = pd.to_datetime(vito['DateTime'],format='%Y-%m-%d %H%M')
vito.index = vito['DateTime']
del vito['DateTime']
# make data into floats
for i in vito.columns:
    vito[i] = vito[i].astype(float)
# replace fill values with nans:
vito.replace(444.0, np.nan, inplace=True)
# resample to daily resolution
del vito['hour']
agg_dict = dict.fromkeys([col for col in vito.columns if col != 'wind_direction'], 'mean')
agg_dict['wind_direction'] = prevailing_wind_direction
vito = vito.resample('1D').agg(agg_dict)

vito
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 276/276 [00:08<00:00, 31.89it/s]
# C:\Users\Homo Naledi\AppData\Local\Temp\ipykernel_13484\2800808839.py:3: RuntimeWarning: Mean of empty slice
#   sin_mean = np.nanmean(np.sin(rad))
# C:\Users\Homo Naledi\AppData\Local\Temp\ipykernel_13484\2800808839.py:4: RuntimeWarning: Mean of empty slice
#   cos_mean = np.nanmean(np.cos(rad))
#               year    doy  month   day  temperature     pressure  wind_speed  \
# DateTime
# 2001-09-01  2001.0  244.0    9.0   1.0   -29.100000   996.429167    1.233333
# 2001-09-02  2001.0  245.0    9.0   2.0   -32.122727  1002.050000    1.772727
# 2001-09-03  2001.0  246.0    9.0   3.0   -28.838889   996.100000    1.633333
# 2001-09-04  2001.0  247.0    9.0   4.0   -23.875000   979.960000    2.090000
# 2001-09-05  2001.0  248.0    9.0   5.0   -27.855000   976.675000    3.605000
# ...            ...    ...    ...   ...          ...          ...         ...
# 2024-12-27  2024.0  362.0   12.0  27.0    -2.845833   983.720833    4.004167
# 2024-12-28  2024.0  363.0   12.0  28.0    -3.654167   986.000000    4.033333
# 2024-12-29  2024.0  364.0   12.0  29.0    -3.666667   987.208333    2.995833
# 2024-12-30  2024.0  365.0   12.0  30.0    -2.212500   980.312500    6.433333
# 2024-12-31  2024.0  366.0   12.0  31.0    -1.429167   983.837500    1.962500
#
#             relative_humidity   ?  wind_direction
# DateTime
# 2001-09-01          68.633333 NaN       61.538269
# 2001-09-02          71.581818 NaN      198.594071
# 2001-09-03          62.533333 NaN      165.214198
# 2001-09-04          46.780000 NaN       39.954682
# 2001-09-05          54.060000 NaN      213.536965
# ...                       ...  ..             ...
# 2024-12-27          95.089474 NaN      272.974598
# 2024-12-28          91.877273 NaN       25.381716
# 2024-12-29          94.460870 NaN        7.521921
# 2024-12-30          74.279167 NaN      233.514647
# 2024-12-31          81.133333 NaN       10.038540
#
# [8523 rows x 10 columns]

# %%
vito.to_csv('../../Data/capebird/capebird.csv')
